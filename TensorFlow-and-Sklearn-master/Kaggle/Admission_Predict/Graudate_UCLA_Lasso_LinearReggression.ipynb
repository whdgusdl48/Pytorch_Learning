# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('Admission_Predict.csv')
data
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  ...    Research  Chance of Admit
# count  400.000000  400.000000  ...  400.000000        400.000000
# mean   200.500000  316.807500  ...    0.547500          0.724350
# std    115.614301   11.473646  ...    0.498362          0.142609
# min      1.000000  290.000000  ...    0.000000          0.340000
# 25%    100.750000  308.000000  ...    0.000000          0.640000
# 50%    200.500000  317.000000  ...    1.000000          0.730000
# 75%    300.250000  325.000000  ...    1.000000          0.830000
# max    400.000000  340.000000  ...    1.000000          0.970000
#
# [8 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
#상위 25% 기준으로 데이터를 분석한다.

large = data[data['Chance of Admit '] >= 0.75]['GRE Score']
smaller= data[data['Chance of Admit '] < 0.75]['GRE Score']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean     325.500000
# std        7.992664
# min      303.000000
# 25%      321.000000
# 50%      325.000000
# 75%      331.000000
# max      340.000000
# Name: GRE Score, dtype: float64
# count    220.000000
# mean     309.695455
# std        8.643787
# min      290.000000
# 25%      302.750000
# 50%      311.000000
# 75%      316.000000
# max      329.000000
# Name: GRE Score, dtype: float64

# %%
large = data[data['Chance of Admit '] >= 0.75]['TOEFL Score']
smaller= data[data['Chance of Admit '] < 0.75]['TOEFL Score']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean     111.916667
# std        4.620666
# min       98.000000
# 25%      109.000000
# 50%      112.000000
# 75%      115.000000
# max      120.000000
# Name: TOEFL Score, dtype: float64
# count    220.000000
# mean     103.722727
# std        4.394936
# min       92.000000
# 25%      100.000000
# 50%      104.000000
# 75%      107.000000
# max      115.000000
# Name: TOEFL Score, dtype: float64

# %%
large = data[data['Chance of Admit '] >= 0.75]['University Rating']
smaller= data[data['Chance of Admit '] < 0.75]['University Rating']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean       3.894444
# std        0.930533
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: University Rating, dtype: float64
# count    220.000000
# mean       2.427273
# std        0.838122
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000
# Name: University Rating, dtype: float64

# %%
large = data[data['Chance of Admit '] >= 0.75]['SOP']
smaller= data[data['Chance of Admit '] < 0.75]['SOP']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean       4.080556
# std        0.709402
# min        2.000000
# 25%        3.500000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: SOP, dtype: float64
# count    220.000000
# mean       2.843182
# std        0.862300
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.500000
# max        5.000000
# Name: SOP, dtype: float64

# %%
large = data[data['Chance of Admit '] >= 0.75]['LOR ']
smaller= data[data['Chance of Admit '] < 0.75]['LOR ']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean       4.005556
# std        0.745543
# min        1.500000
# 25%        3.500000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: LOR , dtype: float64
# count    220.000000
# mean       3.000000
# std        0.747904
# min        1.000000
# 25%        2.500000
# 50%        3.000000
# 75%        3.500000
# max        5.000000
# Name: LOR , dtype: float64

# %%
large = data[data['Chance of Admit '] >= 0.75]['CGPA']
smaller= data[data['Chance of Admit '] < 0.75]['CGPA']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean       9.084389
# std        0.388569
# min        8.000000
# 25%        8.790000
# 50%        9.105000
# 75%        9.352500
# max        9.920000
# Name: CGPA, dtype: float64
# count    220.000000
# mean       8.201727
# std        0.415045
# min        6.800000
# 25%        7.957500
# 50%        8.225000
# 75%        8.500000
# max        9.220000
# Name: CGPA, dtype: float64

# %%
large = data[data['Chance of Admit '] >= 0.75]['Research']
smaller= data[data['Chance of Admit '] < 0.75]['Research']
print(large.describe())
print(smaller.describe())
plt.plot(np.arange(0,len(large)),large)
plt.show()
plt.plot(np.arange(0,len(smaller)),smaller)
plt.show()
# Out:
# count    180.000000
# mean       0.833333
# std        0.373718
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Research, dtype: float64
# count    220.000000
# mean       0.313636
# std        0.465029
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Research, dtype: float64

# %%
sns.countplot(x='Research',data = data)
plt.show()

# %%
data_corr = data.corr()
data_corr
# Out:
#                    Serial No.  GRE Score  ...  Research  Chance of Admit
# Serial No.           1.000000  -0.097526  ... -0.063138          0.042336
# GRE Score           -0.097526   1.000000  ...  0.580391          0.802610
# TOEFL Score         -0.147932   0.835977  ...  0.489858          0.791594
# University Rating   -0.169948   0.668976  ...  0.447783          0.711250
# SOP                 -0.166932   0.612831  ...  0.444029          0.675732
# LOR                 -0.088221   0.557555  ...  0.396859          0.669889
# CGPA                -0.045608   0.833060  ...  0.521654          0.873289
# Research            -0.063138   0.580391  ...  1.000000          0.553202
# Chance of Admit      0.042336   0.802610  ...  0.553202          1.000000
#
# [9 rows x 9 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_corr, annot=True)
plt.show()

# %%
train_y = data['Chance of Admit ']
del data['Chance of Admit ']
del data['Research']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Chance of Admit '
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-6d8ae688b087> in <module>()
# ----> 1 train_y = data['Chance of Admit ']
#       2 del data['Chance of Admit ']
#       3 del data['Research']
#       4 del data['LOR ']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Chance of Admit '

# %%
train_y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
del data['LOR ']

# %%
del data['Serial No.']

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  CGPA
# 0          337          118                  4  4.5  9.65
# 1          324          107                  4  4.0  8.87
# 2          316          104                  3  3.0  8.00
# 3          322          110                  3  3.5  8.67
# 4          314          103                  2  2.0  8.21
# ..         ...          ...                ...  ...   ...
# 395        324          110                  3  3.5  9.04
# 396        325          107                  3  3.0  9.11
# 397        330          116                  4  5.0  9.45
# 398        312          103                  3  3.5  8.78
# 399        333          117                  4  5.0  9.66
#
# [400 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn import tree
model = LinearRegression()
model.fit(data,train_y)

print(model.score(data,train_y))
new_data = model.predict(data)
# Out:
# 0.790258496787017

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=1.0)
model.fit(data,train_y)

print(model.score(data,train_y))
new_data = model.predict(data)
# Out:
# 0.7901919118559158

# %%
from sklearn.linear_model import Lasso
model = Lasso()
model.fit(data,train_y)

print(model.score(data,train_y))
new_data = model.predict(data)
# Out:
# 0.26879985044501187

# %%
test = pd.read_csv('Admission_Predict_Ver1.1.csv')
test
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 495         496        332          108  ...  9.02         1              0.87
# 496         497        337          117  ...  9.87         1              0.96
# 497         498        330          120  ...  9.56         1              0.93
# 498         499        312          103  ...  8.43         0              0.73
# 499         500        327          113  ...  9.04         0              0.84
#
# [500 rows x 9 columns]

# %%
test_y = test['Chance of Admit ']
del test['Chance of Admit ']

# %%
del test['Research']
del test['LOR ']
del test['Serial No.']

# %%
model.predict(test)
# Linear Reggression
# Out:
# array([0.94896006, 0.78758175, 0.63260208, 0.75160004, 0.63651488,
#        0.89465225, 0.68215998, 0.5849775 , 0.5704366 , 0.73986355,
#        0.71348652, 0.8210653 , 0.83877812, 0.63172484, 0.65091502,
#        0.67315216, 0.74046368, 0.6515249 , 0.7630737 , 0.6669268 ,
#        0.61789718, 0.7386352 , 0.91699943, 0.96392229, 0.9742095 ,
#        0.96332216, 0.79165224, 0.49214314, 0.42854758, 0.49573345,
#        0.58309001, 0.70128255, 0.9078583 , 0.94501099, 0.94575854,
#        0.84520439, 0.64911061, 0.54001479, 0.52453553, 0.58109056,
#        0.63281601, 0.64825576, 0.6853727 , 0.86368931, 0.88850767,
#        0.83672663, 0.88112108, 0.97161348, 0.77274161, 0.73581372,
#        0.64651065, 0.58071877, 0.71912268, 0.69970881, 0.66086659,
#        0.60019589, 0.5424533 , 0.52569172, 0.40978083, 0.64387887,
#        0.6107952 , 0.63814019, 0.62472949, 0.70075576, 0.76111614,
#        0.80496835, 0.81459287, 0.71760122, 0.81161421, 0.85754474,
#        0.94914814, 0.95910765, 0.88242032, 0.7931319 , 0.74999359,
#        0.74288902, 0.77068946, 0.60585184, 0.49633261, 0.44346916,
#        0.62136331, 0.9447602 , 0.84780481, 0.87553584, 0.93157607,
#        0.74279182, 0.70070456, 0.67305593, 0.66693381, 0.76369902,
#        0.62968162, 0.54727655, 0.57915202, 0.55674761, 0.53950487,
#        0.57317924, 0.59100666, 0.837771  , 0.89040899, 0.79213192,
#        0.7169499 , 0.62880548, 0.66353983, 0.69765323, 0.81495372,
#        0.75594897, 0.85261291, 0.91683052, 0.90818341, 0.71905814,
#        0.69828165, 0.76098855, 0.65384217, 0.72721357, 0.6858688 ,
#        0.77918609, 0.67710025, 0.50551519, 0.47232162, 0.7850621 ,
#        0.94308435, 0.93169815, 0.66905452, 0.65652337, 0.67023657,
#        0.6651877 , 0.84934102, 0.74767244, 0.82145475, 0.91370429,
#        0.96355215, 0.72299339, 0.71400571, 0.7950402 , 0.88512069,
#        0.75323575, 0.6940925 , 0.62357277, 0.82670843, 0.78025319,
#        0.82428516, 0.88158434, 0.90629689, 0.99574931, 0.78819065,
#        0.73048269, 0.68795929, 0.82403258, 0.9644707 , 0.65443399,
#        0.90015507, 0.89744349, 0.83416085, 0.75066343, 0.78073643,
#        0.72551073, 0.66975639, 0.63415374, 0.61666199, 0.53760698,
#        0.58047073, 0.48021143, 0.71437972, 0.713744  , 0.83050939,
#        0.81620436, 0.64256113, 0.64878484, 0.52100956, 0.59364884,
#        0.60860943, 0.86987289, 0.82420862, 0.84681863, 0.80359175,
#        0.79194711, 0.86960129, 0.79292123, 0.63854429, 0.64245107,
#        0.6208305 , 0.65687381, 0.5595691 , 0.75402508, 0.66630684,
#        0.84388435, 0.73424368, 0.92631088, 0.89951481, 0.84354772,
#        0.8478812 , 0.81614714, 0.82209813, 0.9402749 , 0.74728038,
#        0.67801977, 0.63705504, 0.66127328, 0.68805895, 0.73011485,
#        0.69900722, 0.69928114, 1.00362858, 0.98123524, 0.66816265,
#        0.51454754, 0.59823476, 0.62035195, 0.62423941, 0.61789182,
#        0.82061602, 0.84632091, 0.96103921, 0.97206179, 0.90303378,
#        0.90332084, 0.84962808, 0.81949786, 0.80069045, 0.68178173,
#        0.7281217 , 0.72372484, 0.79549127, 0.67607767, 0.63089226,
#        0.56621756, 0.67762154, 0.70159613, 0.7510682 , 0.80833987,
#        0.71756823, 0.69081215, 0.65320579, 0.59196422, 0.88947401,
#        0.86150696, 0.8410931 , 0.87043839, 0.65989764, 0.54083109,
#        0.51642804, 0.63911968, 0.78006921, 0.81628856, 0.6954361 ,
#        0.82347927, 0.72996578, 0.67090218, 0.78212849, 0.7725898 ,
#        0.71576249, 0.73758072, 0.68474411, 0.94099058, 0.83044065,
#        0.69146057, 0.68457475, 0.73135733, 0.77279995, 0.9011489 ,
#        0.84704083, 0.6388749 , 0.64606463, 0.76693627, 0.75728931,
#        0.7057129 , 0.66809273, 0.65752708, 0.84778497, 0.68854449,
#        0.62823463, 0.53631554, 0.48477215, 0.5797734 , 0.58844638,
#        0.78930604, 0.90541475, 0.70211867, 0.66658691, 0.68629466,
#        0.7104661 , 0.80111796, 0.73840617, 0.77445208, 0.94597473,
#        0.88534176, 0.89606786, 0.84844492, 0.78435668, 0.77531846,
#        0.55638499, 0.5545695 , 0.5611305 , 0.61752623, 0.65406385,
#        0.69000216, 0.71710839, 0.8323904 , 0.86084263, 0.71182061,
#        0.60886514, 0.7351996 , 0.69795344, 0.73091392, 0.67382265,
#        0.76379198, 0.81339068, 0.81898959, 0.7058784 , 0.7200079 ,
#        0.73786601, 0.84300496, 0.77869601, 0.59769577, 0.61789019,
#        0.61080723, 0.54629638, 0.55262754, 0.76823647, 0.7820365 ,
#        0.71201094, 0.71288543, 0.65773009, 0.60980627, 0.67324675,
#        0.83644998, 0.5797123 , 0.54674908, 0.78682267, 0.54293102,
#        0.7689564 , 0.63016291, 0.65032596, 0.71939411, 0.73545092,
#        0.83084326, 0.75679648, 0.92704462, 0.78004498, 0.76583729,
#        0.69070877, 0.77235052, 0.650607  , 0.60937341, 0.45965616,
#        0.514581  , 0.52147036, 0.45100853, 0.46557529, 0.62005106,
#        0.67957777, 0.76756598, 0.59202144, 0.61723351, 0.51922366,
#        0.63894527, 0.77346428, 0.57880759, 0.57091986, 0.69204911,
#        0.751319  , 0.91935455, 0.89844721, 0.64154033, 0.74155662,
#        0.86092066, 0.68947731, 0.50355126, 0.52129952, 0.56228068,
#        0.63498646, 0.82763573, 0.94524589, 0.72636702, 0.57086264,
#        0.53748475, 0.4831215 , 0.47756487, 0.51739712, 0.64297868,
#        0.75901197, 0.728951  , 0.83495292, 0.62041859, 0.95882498,
#        0.97688973, 0.57558623, 0.61127472, 0.52417644, 0.71227378,
#        0.6379669 , 0.71929787, 0.83685422, 0.72450048, 0.85911395,
#        0.80423201, 0.80463023, 0.90584323, 0.72614058, 0.94238264,
#        0.61870649, 0.66781608, 0.78878134, 0.86999951, 0.55989889,
#        0.51355796, 0.65550629, 0.57196828, 0.53212935, 0.55871831,
#        0.50351292, 0.60543326, 0.61313798, 0.61971719, 0.71691074,
#        0.77631713, 0.65058116, 0.59216644, 0.62500875, 0.59058859,
#        0.50169989, 0.7870213 , 0.81118395, 0.9394994 , 0.89287577,
#        0.93301395, 0.70256245, 0.69981639, 0.70995015, 0.88448758,
#        0.64543316, 0.75709573, 0.84895157, 0.73637208, 0.63845586,
#        0.56480992, 0.50438711, 0.56503649, 0.70005062, 0.66577335,
#        0.56761498, 0.7449813 , 0.90318559, 0.84844053, 0.86086068,
#        0.85877115, 0.93255852, 0.78118474, 0.7556185 , 0.77353709,
#        0.78223675, 0.85530079, 0.92082202, 0.73213609, 0.61359848,
#        0.53597551, 0.55232993, 0.49134683, 0.66431108, 0.87729425,
#        0.74406943, 0.60705567, 0.61606952, 0.5982187 , 0.45560812,
#        0.63111444, 0.72354893, 0.75317526, 0.7939656 , 0.84695225,
#        0.84706668, 0.6233054 , 0.89571822, 0.64526767, 0.61963188,
#        0.57707891, 0.61743912, 0.65541837, 0.70562709, 0.81251114,
#        0.77395613, 0.72737236, 0.79831989, 0.62544324, 0.62907873,
#        0.64535349, 0.67897942, 0.84544301, 0.74637662, 0.68787301,
#        0.61749471, 0.56185369, 0.54979097, 0.5937953 , 0.64131649,
#        0.84042974, 0.98791507, 0.93549979, 0.69343239, 0.8347829 ])

# %%
print(model.score(test,test_y))
# Out:
# 0.8101972619629448

# %%
model.predict(test)
# Lasso Reggression
# Out:
# array([0.94824173, 0.78757184, 0.63451857, 0.75207099, 0.63641695,
#        0.8946657 , 0.68424673, 0.58591293, 0.56972987, 0.74048476,
#        0.71491189, 0.82123502, 0.8387204 , 0.63390912, 0.65174746,
#        0.67393178, 0.74022827, 0.65439381, 0.76285297, 0.66551111,
#        0.62026341, 0.74116004, 0.91648617, 0.96342448, 0.97300217,
#        0.96368097, 0.79259422, 0.49291297, 0.42962663, 0.4985438 ,
#        0.58197101, 0.70317936, 0.90764432, 0.94441927, 0.9432672 ,
#        0.84457368, 0.64813473, 0.5399199 , 0.52699405, 0.58410608,
#        0.6349845 , 0.64884234, 0.684632  , 0.86481034, 0.88766824,
#        0.83670638, 0.88087632, 0.97132809, 0.77234076, 0.73815001,
#        0.64590719, 0.5812099 , 0.72486712, 0.70366001, 0.66403336,
#        0.60364805, 0.54629424, 0.52726764, 0.41421445, 0.64324782,
#        0.61082524, 0.63848434, 0.62449243, 0.7008622 , 0.76161519,
#        0.80520898, 0.81423511, 0.71696067, 0.80921781, 0.85781288,
#        0.94861613, 0.95767556, 0.88090844, 0.79185315, 0.74805519,
#        0.74390717, 0.77139704, 0.6045393 , 0.4970628 , 0.4435394 ,
#        0.62251608, 0.94542385, 0.84708693, 0.87453942, 0.9319833 ,
#        0.74300046, 0.70161792, 0.67407164, 0.66922227, 0.76393625,
#        0.6324567 , 0.54923968, 0.57873286, 0.55667473, 0.54071437,
#        0.57394363, 0.59121058, 0.83919871, 0.89138616, 0.79236231,
#        0.71797288, 0.62939145, 0.66452744, 0.69792604, 0.81435994,
#        0.75564078, 0.85239696, 0.91645817, 0.90845509, 0.71862351,
#        0.69834027, 0.76178686, 0.65355446, 0.72785829, 0.68573274,
#        0.77731594, 0.67503647, 0.50742166, 0.47466919, 0.78498853,
#        0.94304189, 0.93193498, 0.66880293, 0.65749093, 0.66916805,
#        0.66189812, 0.84765381, 0.74750088, 0.82064307, 0.91452348,
#        0.96217579, 0.72266998, 0.71392593, 0.79629567, 0.8851913 ,
#        0.75280643, 0.69447415, 0.62328004, 0.82656133, 0.7775823 ,
#        0.82314442, 0.88098298, 0.90573767, 0.99435834, 0.78732246,
#        0.73024526, 0.68736925, 0.82319526, 0.96280698, 0.6548919 ,
#        0.89942518, 0.89823831, 0.83446972, 0.75013088, 0.78013156,
#        0.7246761 , 0.6697765 , 0.63352238, 0.61653378, 0.53643319,
#        0.58140617, 0.4809215 , 0.71489706, 0.71365245, 0.83103434,
#        0.8165265 , 0.64179901, 0.6485722 , 0.52013845, 0.59403128,
#        0.60905982, 0.87143028, 0.82325412, 0.84587882, 0.80336831,
#        0.79229634, 0.87044099, 0.79151769, 0.63958665, 0.64216287,
#        0.62087676, 0.65578322, 0.55968477, 0.75345508, 0.6664915 ,
#        0.84404096, 0.73387127, 0.92668829, 0.89952843, 0.84403139,
#        0.84767098, 0.81628885, 0.82303526, 0.94034739, 0.74671412,
#        0.67689216, 0.63673112, 0.6613388 , 0.68833734, 0.72957376,
#        0.69831238, 0.69970092, 1.00263635, 0.97966926, 0.66649922,
#        0.51497109, 0.59980705, 0.62163942, 0.62438506, 0.61819973,
#        0.8202106 , 0.84629508, 0.9608309 , 0.97112801, 0.90267286,
#        0.90359236, 0.84857331, 0.81833499, 0.80015956, 0.68174268,
#        0.72683487, 0.72415128, 0.79678054, 0.67558458, 0.63061177,
#        0.56507231, 0.67729904, 0.70144888, 0.75165617, 0.80775572,
#        0.71683828, 0.69201868, 0.65338015, 0.59146425, 0.88960026,
#        0.8611663 , 0.84046836, 0.8708972 , 0.65922935, 0.53987551,
#        0.51669513, 0.63976937, 0.78092785, 0.81589317, 0.69452122,
#        0.82352808, 0.72882185, 0.66971082, 0.78190243, 0.77239717,
#        0.71554408, 0.73395439, 0.68341824, 0.93960369, 0.82992666,
#        0.69250853, 0.68328247, 0.73114722, 0.77328711, 0.90160293,
#        0.8470843 , 0.64027405, 0.64501325, 0.76673159, 0.75705065,
#        0.70393758, 0.66701633, 0.65889123, 0.84781084, 0.68979256,
#        0.62786087, 0.53536162, 0.48386422, 0.57908474, 0.58885057,
#        0.78851311, 0.90484354, 0.70073985, 0.66519312, 0.68338457,
#        0.70958714, 0.79945888, 0.73722088, 0.77350604, 0.94497257,
#        0.88568808, 0.89762214, 0.84917071, 0.78290501, 0.77366845,
#        0.55858272, 0.55438568, 0.56009814, 0.61709646, 0.65364321,
#        0.6886824 , 0.71616834, 0.83220389, 0.86046053, 0.71091227,
#        0.6098332 , 0.73397074, 0.69819856, 0.73163198, 0.67326596,
#        0.76348798, 0.81229909, 0.81910573, 0.70584419, 0.71991663,
#        0.73690671, 0.84233851, 0.77720857, 0.5978681 , 0.61804552,
#        0.61114078, 0.54586045, 0.55089107, 0.76798821, 0.78357521,
#        0.71252611, 0.71394388, 0.65807909, 0.60893217, 0.67363772,
#        0.83594821, 0.57912464, 0.54649953, 0.78785388, 0.54212006,
#        0.7702707 , 0.63088573, 0.65109498, 0.71970337, 0.73557617,
#        0.83035895, 0.75625832, 0.9272535 , 0.78099053, 0.76687359,
#        0.69063441, 0.7727785 , 0.65102111, 0.60906245, 0.46061923,
#        0.51687247, 0.5220329 , 0.45149942, 0.46777402, 0.62094392,
#        0.68085537, 0.76865403, 0.59170191, 0.61699407, 0.51961363,
#        0.63986472, 0.77381494, 0.57976273, 0.5737724 , 0.69204427,
#        0.75214486, 0.91838737, 0.89963861, 0.6403143 , 0.73927083,
#        0.86119879, 0.69048546, 0.50505123, 0.51955589, 0.56087163,
#        0.63463269, 0.82588431, 0.94469204, 0.72697198, 0.57353474,
#        0.53866853, 0.48431531, 0.47726163, 0.51781883, 0.64104477,
#        0.75801566, 0.72833052, 0.83431007, 0.61932062, 0.95759523,
#        0.97571414, 0.57551209, 0.61128709, 0.52334312, 0.71333035,
#        0.63761717, 0.71834995, 0.8365347 , 0.72283691, 0.85868009,
#        0.80326506, 0.80285817, 0.90536736, 0.72441152, 0.94137456,
#        0.61800113, 0.66792937, 0.78812915, 0.8700341 , 0.56213622,
#        0.51581953, 0.65809362, 0.57182255, 0.53301348, 0.55726554,
#        0.50435844, 0.6047313 , 0.61529168, 0.62161931, 0.71904414,
#        0.77697109, 0.65242285, 0.59558066, 0.62645137, 0.59084808,
#        0.50372714, 0.78620258, 0.81072681, 0.93947473, 0.89158443,
#        0.92944151, 0.70188762, 0.69823713, 0.70771702, 0.88681868,
#        0.64679483, 0.7567996 , 0.84824576, 0.73758607, 0.63868706,
#        0.56705154, 0.50847905, 0.56742497, 0.69958021, 0.6644292 ,
#        0.56890686, 0.74500413, 0.90261645, 0.84833154, 0.86027617,
#        0.85986417, 0.93110401, 0.77993147, 0.75276634, 0.7703025 ,
#        0.78207811, 0.85458529, 0.91951779, 0.73065707, 0.61471339,
#        0.53723066, 0.55199726, 0.49153971, 0.6623739 , 0.87631178,
#        0.74429603, 0.60662953, 0.61793786, 0.60028488, 0.45774494,
#        0.63032398, 0.72208333, 0.7524383 , 0.79418797, 0.84670052,
#        0.84568255, 0.62382367, 0.89440131, 0.6463815 , 0.62154395,
#        0.57798228, 0.61756065, 0.65663955, 0.70590998, 0.81278366,
#        0.77188949, 0.72852648, 0.79982143, 0.62814651, 0.63202824,
#        0.64440909, 0.67907904, 0.84526265, 0.74708343, 0.68756266,
#        0.61764409, 0.56268905, 0.55125459, 0.59191119, 0.63913256,
#        0.84116503, 0.98669621, 0.93515975, 0.69380803, 0.83524459])

# %%
print(model.score(test,test_y))
# Out:
# 0.8101947612217626
