# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dogs-vs-cats/test/test/8547.jpg
# /kaggle/input/dogs-vs-cats/test/test/7635.jpg
# /kaggle/input/dogs-vs-cats/test/test/11802.jpg
# /kaggle/input/dogs-vs-cats/test/test/11479.jpg
# /kaggle/input/dogs-vs-cats/test/test/6258.jpg
# /kaggle/input/dogs-vs-cats/test/test/5488.jpg
# /kaggle/input/dogs-vs-cats/test/test/5421.jpg
# /kaggle/input/dogs-vs-cats/test/test/11036.jpg
# /kaggle/input/dogs-vs-cats/test/test/9885.jpg
# /kaggle/input/dogs-vs-cats/test/test/9744.jpg
# /kaggle/input/dogs-vs-cats/test/test/5340.jpg
# /kaggle/input/dogs-vs-cats/test/test/3683.jpg
# /kaggle/input/dogs-vs-cats/test/test/5490.jpg
# /kaggle/input/dogs-vs-cats/test/test/5814.jpg
# /kaggle/input/dogs-vs-cats/test/test/6256.jpg
# /kaggle/input/dogs-vs-cats/test/test/919.jpg
# /kaggle/input/dogs-vs-cats/test/test/4353.jpg
# /kaggle/input/dogs-vs-cats/test/test/5952.jpg
# /kaggle/input/dogs-vs-cats/test/test/1357.jpg
# /kaggle/input/dogs-vs-cats/test/test/9472.jpg
# /kaggle/input/dogs-vs-cats/test/test/5807.jpg
# /kaggle/input/dogs-vs-cats/test/test/12289.jpg
# /kaggle/input/dogs-vs-cats/test/test/9699.jpg
# /kaggle/input/dogs-vs-cats/test/test/7386.jpg
# /kaggle/input/dogs-vs-cats/test/test/10132.jpg
# /kaggle/input/dogs-vs-cats/test/test/3322.jpg
# /kaggle/input/dogs-vs-cats/test/test/10528.jpg
# /kaggle/input/dogs-vs-cats/test/test/7445.jpg
# /kaggle/input/dogs-vs-cats/test/test/11354.jpg
# /kaggle/input/dogs-vs-cats/test/test/11324.jpg
# /kaggle/input/dogs-vs-cats/test/test/795.jpg
# /kaggle/input/dogs-vs-cats/test/test/5916.jpg
# /kaggle/input/dogs-vs-cats/test/test/84.jpg
# /kaggle/input/dogs-vs-cats/test/test/3442.jpg
# /kaggle/input/dogs-vs-cats/test/test/4970.jpg
# /kaggle/input/dogs-vs-cats/test/test/2520.jpg
# /kaggle/input/dogs-vs-cats/test/test/33.jpg
# /kaggle/input/dogs-vs-cats/test/test/3469.jpg
# /kaggle/input/dogs-vs-cats/test/test/10547.jpg
# /kaggle/input/dogs-vs-cats/test/test/6587.jpg
# /kaggle/input/dogs-vs-cats/test/test/1505.jpg
# /kaggle/input/dogs-vs-cats/test/test/6739.jpg
# /kaggle/input/dogs-vs-cats/test/test/11097.jpg
# /kaggle/input/dogs-vs-cats/test/test/3879.jpg
# /kaggle/input/dogs-vs-cats/test/test/6472.jpg
# /kaggle/input/dogs-vs-cats/test/test/5832.jpg
# /kaggle/input/dogs-vs-cats/test/test/698.jpg
# /kaggle/input/dogs-vs-cats/test/test/1548.jpg
# /kaggle/input/dogs-vs-cats/test/test/2439.jpg
# /kaggle/input/dogs-vs-cats/test/test/9849.jpg
# /kaggle/input/dogs-vs-cats/test/test/2299.jpg
# /kaggle/input/dogs-vs-cats/test/test/6535.jpg
# /kaggle/input/dogs-vs-cats/test/test/7731.jpg
# /kaggle/input/dogs-vs-cats/test/test/5141.jpg
# /kaggle/input/dogs-vs-cats/test/test/9910.jpg
# /kaggle/input/dogs-vs-cats/test/test/10105.jpg
# /kaggle/input/dogs-vs-cats/test/test/5703.jpg
# /kaggle/input/dogs-vs-cats/test/test/3885.jpg
# /kaggle/input/dogs-vs-cats/test/test/6734.jpg
# /kaggle/input/dogs-vs-cats/test/test/1951.jpg
# /kaggle/input/dogs-vs-cats/test/test/8703.jpg
# /kaggle/input/dogs-vs-cats/test/test/5272.jpg
# /kaggle/input/dogs-vs-cats/test/test/7081.jpg
# /kaggle/input/dogs-vs-cats/test/test/10578.jpg
# /kaggle/input/dogs-vs-cats/test/test/7451.jpg
# /kaggle/input/dogs-vs-cats/test/test/2845.jpg
# /kaggle/input/dogs-vs-cats/test/test/2858.jpg
# /kaggle/input/dogs-vs-cats/test/test/1374.jpg
# /kaggle/input/dogs-vs-cats/test/test/6043.jpg
# /kaggle/input/dogs-vs-cats/test/test/11372.jpg
# /kaggle/input/dogs-vs-cats/test/test/4513.jpg
# /kaggle/input/dogs-vs-cats/test/test/9939.jpg
# /kaggle/input/dogs-vs-cats/test/test/3511.jpg
# /kaggle/input/dogs-vs-cats/test/test/944.jpg
# /kaggle/input/dogs-vs-cats/test/test/10380.jpg
# /kaggle/input/dogs-vs-cats/test/test/12158.jpg
# /kaggle/input/dogs-vs-cats/test/test/2550.jpg
# /kaggle/input/dogs-vs-cats/test/test/8377.jpg
# /kaggle/input/dogs-vs-cats/test/test/4524.jpg
# /kaggle/input/dogs-vs-cats/test/test/5414.jpg
# /kaggle/input/dogs-vs-cats/test/test/11420.jpg
# /kaggle/input/dogs-vs-cats/test/test/3306.jpg
# /kaggle/input/dogs-vs-cats/test/test/5103.jpg
# /kaggle/input/dogs-vs-cats/test/test/10473.jpg
# /kaggle/input/dogs-vs-cats/test/test/11488.jpg
# /kaggle/input/dogs-vs-cats/test/test/1919.jpg
# /kaggle/input/dogs-vs-cats/test/test/1594.jpg
# /kaggle/input/dogs-vs-cats/test/test/3316.jpg
# /kaggle/input/dogs-vs-cats/test/test/2614.jpg
# /kaggle/input/dogs-vs-cats/test/test/3900.jpg
# /kaggle/input/dogs-vs-cats/test/test/4177.jpg
# /kaggle/input/dogs-vs-cats/test/test/5568.jpg
# /kaggle/input/dogs-vs-cats/test/test/2131.jpg
# /kaggle/input/dogs-vs-cats/test/test/1194.jpg
# /kaggle/input/dogs-vs-cats/test/test/8971.jpg
# /kaggle/input/dogs-vs-cats/test/test/1729.jpg
# /kaggle/input/dogs-vs-cats/test/test/3078.jpg
# /kaggle/input/dogs-vs-cats/test/test/1000.jpg
# /kaggle/input/dogs-vs-cats/test/test/713.jpg
# /kaggle/input/dogs-vs-cats/test/test/10005.jpg
# /kaggle/input/dogs-vs-cats/test/test/5160.jpg
# /kaggle/input/dogs-vs-cats/test/test/6323.jpg
# /kaggle/input/dogs-vs-cats/test/test/6838.jpg
# /kaggle/input/dogs-vs-cats/test/test/298.jpg
# /kaggle/input/dogs-vs-cats/test/test/10745.jpg
# /kaggle/input/dogs-vs-cats/test/test/1363.jpg
# /kaggle/input/dogs-vs-cats/test/test/588.jpg
# /kaggle/input/dogs-vs-cats/test/test/2221.jpg
# /kaggle/input/dogs-vs-cats/test/test/428.jpg
# /kaggle/input/dogs-vs-cats/test/test/12334.jpg
# /kaggle/input/dogs-vs-cats/test/test/4168.jpg
# /kaggle/input/dogs-vs-cats/test/test/9440.jpg
# /kaggle/input/dogs-vs-cats/test/test/12114.jpg
# /kaggle/input/dogs-vs-cats/test/test/11353.jpg
# /kaggle/input/dogs-vs-cats/test/test/2161.jpg
# /kaggle/input/dogs-vs-cats/test/test/9237.jpg
# /kaggle/input/dogs-vs-cats/test/test/11474.jpg
# /kaggle/input/dogs-vs-cats/test/test/2423.jpg
# /kaggle/input/dogs-vs-cats/test/test/8197.jpg
# /kaggle/input/dogs-vs-cats/test/test/11186.jpg
# /kaggle/input/dogs-vs-cats/test/test/11041.jpg
# /kaggle/input/dogs-vs-cats/test/test/1206.jpg
# /kaggle/input/dogs-vs-cats/test/test/12363.jpg
# /kaggle/input/dogs-vs-cats/test/test/4444.jpg
# /kaggle/input/dogs-vs-cats/test/test/9055.jpg
# /kaggle/input/dogs-vs-cats/test/test/2672.jpg
# /kaggle/input/dogs-vs-cats/test/test/2949.jpg
# /kaggle/input/dogs-vs-cats/test/test/11545.jpg
# /kaggle/input/dogs-vs-cats/test/test/9130.jpg
# /kaggle/input/dogs-vs-cats/test/test/5615.jpg
# /kaggle/input/dogs-vs-cats/test/test/11181.jpg
# /kaggle/input/dogs-vs-cats/test/test/7190.jpg
# /kaggle/input/dogs-vs-cats/test/test/4593.jpg
# /kaggle/input/dogs-vs-cats/test/test/8367.jpg
# /kaggle/input/dogs-vs-cats/test/test/4648.jpg
# /kaggle/input/dogs-vs-cats/test/test/4061.jpg
# /kaggle/input/dogs-vs-cats/test/test/5724.jpg
# /kaggle/input/dogs-vs-cats/test/test/1358.jpg
# /kaggle/input/dogs-vs-cats/test/test/6558.jpg
# /kaggle/input/dogs-vs-cats/test/test/4770.jpg
# /kaggle/input/dogs-vs-cats/test/test/568.jpg
# /kaggle/input/dogs-vs-cats/test/test/10072.jpg
# /kaggle/input/dogs-vs-cats/test/test/120.jpg
# /kaggle/input/dogs-vs-cats/test/test/6687.jpg
# /kaggle/input/dogs-vs-cats/test/test/7699.jpg
# /kaggle/input/dogs-vs-cats/test/test/2717.jpg
# /kaggle/input/dogs-vs-cats/test/test/2630.jpg
# /kaggle/input/dogs-vs-cats/test/test/526.jpg
# /kaggle/input/dogs-vs-cats/test/test/10970.jpg
# /kaggle/input/dogs-vs-cats/test/test/4716.jpg
# /kaggle/input/dogs-vs-cats/test/test/4143.jpg
# /kaggle/input/dogs-vs-cats/test/test/10671.jpg
# /kaggle/input/dogs-vs-cats/test/test/5095.jpg
# /kaggle/input/dogs-vs-cats/test/test/11250.jpg
# /kaggle/input/dogs-vs-cats/test/test/3787.jpg
# /kaggle/input/dogs-vs-cats/test/test/9818.jpg
# /kaggle/input/dogs-vs-cats/test/test/11402.jpg
# /kaggle/input/dogs-vs-cats/test/test/9479.jpg
# /kaggle/input/dogs-vs-cats/test/test/5664.jpg
# /kaggle/input/dogs-vs-cats/test/test/9080.jpg
# /kaggle/input/dogs-vs-cats/test/test/8120.jpg
# /kaggle/input/dogs-vs-cats/test/test/4149.jpg
# /kaggle/input/dogs-vs-cats/test/test/10526.jpg
# /kaggle/input/dogs-vs-cats/test/test/6224.jpg
# /kaggle/input/dogs-vs-cats/test/test/5979.jpg
# /kaggle/input/dogs-vs-cats/test/test/1747.jpg
# /kaggle/input/dogs-vs-cats/test/test/4561.jpg
# /kaggle/input/dogs-vs-cats/test/test/4458.jpg
# /kaggle/input/dogs-vs-cats/test/test/2819.jpg
# /kaggle/input/dogs-vs-cats/test/test/181.jpg
# /kaggle/input/dogs-vs-cats/test/test/1359.jpg
# /kaggle/input/dogs-vs-cats/test/test/10779.jpg
# /kaggle/input/dogs-vs-cats/test/test/10983.jpg
# /kaggle/input/dogs-vs-cats/test/test/2353.jpg
# /kaggle/input/dogs-vs-cats/test/test/2574.jpg
# /kaggle/input/dogs-vs-cats/test/test/8847.jpg
# /kaggle/input/dogs-vs-cats/test/test/1442.jpg
# /kaggle/input/dogs-vs-cats/test/test/8348.jpg
# /kaggle/input/dogs-vs-cats/test/test/6378.jpg
# /kaggle/input/dogs-vs-cats/test/test/8527.jpg
# /kaggle/input/dogs-vs-cats/test/test/12008.jpg
# /kaggle/input/dogs-vs-cats/test/test/6970.jpg
# /kaggle/input/dogs-vs-cats/test/test/2648.jpg
# /kaggle/input/dogs-vs-cats/test/test/3200.jpg
# /kaggle/input/dogs-vs-cats/test/test/2552.jpg
# /kaggle/input/dogs-vs-cats/test/test/10514.jpg
# /kaggle/input/dogs-vs-cats/test/test/5115.jpg
# /kaggle/input/dogs-vs-cats/test/test/2010.jpg
# /kaggle/input/dogs-vs-cats/test/test/414.jpg
# /kaggle/input/dogs-vs-cats/test/test/7046.jpg
# /kaggle/input/dogs-vs-cats/test/test/1286.jpg
# /kaggle/input/dogs-vs-cats/test/test/12444.jpg
# /kaggle/input/dogs-vs-cats/test/test/10370.jpg
# /kaggle/input/dogs-vs-cats/test/test/11149.jpg
# /kaggle/input/dogs-vs-cats/test/test/8819.jpg
# /kaggle/input/dogs-vs-cats/test/test/5280.jpg
# /kaggle/input/dogs-vs-cats/test/test/4907.jpg
# /kaggle/input/dogs-vs-cats/test/test/1041.jpg
# /kaggle/input/dogs-vs-cats/test/test/9140.jpg
# /kaggle/input/dogs-vs-cats/test/test/9823.jpg
# /kaggle/input/dogs-vs-cats/test/test/6956.jpg
# /kaggle/input/dogs-vs-cats/test/test/5481.jpg
# /kaggle/input/dogs-vs-cats/test/test/12025.jpg
# /kaggle/input/dogs-vs-cats/test/test/9324.jpg
# /kaggle/input/dogs-vs-cats/test/test/6327.jpg
# /kaggle/input/dogs-vs-cats/test/test/11.jpg
# /kaggle/input/dogs-vs-cats/test/test/5059.jpg
# /kaggle/input/dogs-vs-cats/test/test/3961.jpg
# /kaggle/input/dogs-vs-cats/test/test/9521.jpg
# /kaggle/input/dogs-vs-cats/test/test/6746.jpg
# /kaggle/input/dogs-vs-cats/test/test/277.jpg
# /kaggle/input/dogs-vs-cats/test/test/4937.jpg
# /kaggle/input/dogs-vs-cats/test/test/10971.jpg
# /kaggle/input/dogs-vs-cats/test/test/11160.jpg
# /kaggle/input/dogs-vs-cats/test/test/11886.jpg
# /kaggle/input/dogs-vs-cats/test/test/7599.jpg
# /kaggle/input/dogs-vs-cats/test/test/3435.jpg
# /kaggle/input/dogs-vs-cats/test/test/4837.jpg
# /kaggle/input/dogs-vs-cats/test/test/10520.jpg
# /kaggle/input/dogs-vs-cats/test/test/597.jpg
# /kaggle/input/dogs-vs-cats/test/test/1149.jpg
# /kaggle/input/dogs-vs-cats/test/test/2453.jpg
# /kaggle/input/dogs-vs-cats/test/test/2960.jpg
# /kaggle/input/dogs-vs-cats/test/test/10808.jpg
# /kaggle/input/dogs-vs-cats/test/test/1314.jpg
# /kaggle/input/dogs-vs-cats/test/test/10116.jpg
# /kaggle/input/dogs-vs-cats/test/test/3570.jpg
# /kaggle/input/dogs-vs-cats/test/test/6146.jpg
# /kaggle/input/dogs-vs-cats/test/test/11301.jpg
# /kaggle/input/dogs-vs-cats/test/test/11135.jpg
# /kaggle/input/dogs-vs-cats/test/test/244.jpg
# /kaggle/input/dogs-vs-cats/test/test/5715.jpg
# /kaggle/input/dogs-vs-cats/test/test/6613.jpg
# /kaggle/input/dogs-vs-cats/test/test/6922.jpg
# /kaggle/input/dogs-vs-cats/test/test/8911.jpg
# /kaggle/input/dogs-vs-cats/test/test/12367.jpg
# /kaggle/input/dogs-vs-cats/test/test/7894.jpg
# /kaggle/input/dogs-vs-cats/test/test/10058.jpg
# /kaggle/input/dogs-vs-cats/test/test/9680.jpg
# /kaggle/input/dogs-vs-cats/test/test/12352.jpg
# /kaggle/input/dogs-vs-cats/test/test/9821.jpg
# /kaggle/input/dogs-vs-cats/test/test/6337.jpg
# /kaggle/input/dogs-vs-cats/test/test/4695.jpg
# /kaggle/input/dogs-vs-cats/test/test/1475.jpg
# /kaggle/input/dogs-vs-cats/test/test/9199.jpg
# /kaggle/input/dogs-vs-cats/test/test/11951.jpg
# /kaggle/input/dogs-vs-cats/test/test/9960.jpg
# /kaggle/input/dogs-vs-cats/test/test/9343.jpg
# /kaggle/input/dogs-vs-cats/test/test/4726.jpg
# /kaggle/input/dogs-vs-cats/test/test/8599.jpg
# /kaggle/input/dogs-vs-cats/test/test/3052.jpg
# /kaggle/input/dogs-vs-cats/test/test/10486.jpg
# /kaggle/input/dogs-vs-cats/test/test/10852.jpg
# /kaggle/input/dogs-vs-cats/test/test/10088.jpg
# /kaggle/input/dogs-vs-cats/test/test/3371.jpg
# /kaggle/input/dogs-vs-cats/test/test/11963.jpg
# /kaggle/input/dogs-vs-cats/test/test/6372.jpg
# /kaggle/input/dogs-vs-cats/test/test/217.jpg
# /kaggle/input/dogs-vs-cats/test/test/12197.jpg
# /kaggle/input/dogs-vs-cats/test/test/242.jpg
# /kaggle/input/dogs-vs-cats/test/test/12014.jpg
# /kaggle/input/dogs-vs-cats/test/test/6728.jpg
# /kaggle/input/dogs-vs-cats/test/test/5902.jpg
# /kaggle/input/dogs-vs-cats/test/test/7498.jpg
# /kaggle/input/dogs-vs-cats/test/test/4537.jpg
# /kaggle/input/dogs-vs-cats/test/test/3143.jpg
# /kaggle/input/dogs-vs-cats/test/test/1364.jpg
# /kaggle/input/dogs-vs-cats/test/test/1533.jpg
# /kaggle/input/dogs-vs-cats/test/test/4814.jpg
# /kaggle/input/dogs-vs-cats/test/test/1375.jpg
# /kaggle/input/dogs-vs-cats/test/test/7394.jpg
# /kaggle/input/dogs-vs-cats/test/test/6134.jpg
# /kaggle/input/dogs-vs-cats/test/test/4152.jpg
# /kaggle/input/dogs-vs-cats/test/test/9043.jpg
# /kaggle/input/dogs-vs-cats/test/test/9876.jpg
# /kaggle/input/dogs-vs-cats/test/test/4426.jpg
# /kaggle/input/dogs-vs-cats/test/test/180.jpg
# /kaggle/input/dogs-vs-cats/test/test/11045.jpg
# /kaggle/input/dogs-vs-cats/test/test/7529.jpg
# /kaggle/input/dogs-vs-cats/test/test/11996.jpg
# /kaggle/input/dogs-vs-cats/test/test/4102.jpg
# /kaggle/input/dogs-vs-cats/test/test/10942.jpg
# /kaggle/input/dogs-vs-cats/test/test/11294.jpg
# /kaggle/input/dogs-vs-cats/test/test/10642.jpg
# /kaggle/input/dogs-vs-cats/test/test/8019.jpg
# /kaggle/input/dogs-vs-cats/test/test/7578.jpg
# /kaggle/input/dogs-vs-cats/test/test/407.jpg
# /kaggle/input/dogs-vs-cats/test/test/6115.jpg
# /kaggle/input/dogs-vs-cats/test/test/9329.jpg
# /kaggle/input/dogs-vs-cats/test/test/11205.jpg
# /kaggle/input/dogs-vs-cats/test/test/6314.jpg
# /kaggle/input/dogs-vs-cats/test/test/7030.jpg
# /kaggle/input/dogs-vs-cats/test/test/10688.jpg
# /kaggle/input/dogs-vs-cats/test/test/3939.jpg
# /kaggle/input/dogs-vs-cats/test/test/10388.jpg
# /kaggle/input/dogs-vs-cats/test/test/6194.jpg
# /kaggle/input/dogs-vs-cats/test/test/6984.jpg
# /kaggle/input/dogs-vs-cats/test/test/7065.jpg
# /kaggle/input/dogs-vs-cats/test/test/4694.jpg
# /kaggle/input/dogs-vs-cats/test/test/7089.jpg
# /kaggle/input/dogs-vs-cats/test/test/1317.jpg
# /kaggle/input/dogs-vs-cats/test/test/8318.jpg
# /kaggle/input/dogs-vs-cats/test/test/9250.jpg
# /kaggle/input/dogs-vs-cats/test/test/6668.jpg
# /kaggle/input/dogs-vs-cats/test/test/2519.jpg
# /kaggle/input/dogs-vs-cats/test/test/629.jpg
# /kaggle/input/dogs-vs-cats/test/test/7768.jpg
# /kaggle/input/dogs-vs-cats/test/test/9765.jpg
# /kaggle/input/dogs-vs-cats/test/test/5230.jpg
# /kaggle/input/dogs-vs-cats/test/test/70.jpg
# /kaggle/input/dogs-vs-cats/test/test/10957.jpg
# /kaggle/input/dogs-vs-cats/test/test/237.jpg
# /kaggle/input/dogs-vs-cats/test/test/2866.jpg
# /kaggle/input/dogs-vs-cats/test/test/9863.jpg
# /kaggle/input/dogs-vs-cats/test/test/12275.jpg
# /kaggle/input/dogs-vs-cats/test/test/2633.jpg
# /kaggle/input/dogs-vs-cats/test/test/375.jpg
# /kaggle/input/dogs-vs-cats/test/test/4564.jpg
# /kaggle/input/dogs-vs-cats/test/test/2188.jpg
# /kaggle/input/dogs-vs-cats/test/test/1481.jpg
# /kaggle/input/dogs-vs-cats/test/test/6236.jpg
# /kaggle/input/dogs-vs-cats/test/test/7714.jpg
# /kaggle/input/dogs-vs-cats/test/test/11527.jpg
# /kaggle/input/dogs-vs-cats/test/test/2798.jpg
# /kaggle/input/dogs-vs-cats/test/test/11083.jpg
# /kaggle/input/dogs-vs-cats/test/test/10391.jpg
# /kaggle/input/dogs-vs-cats/test/test/8740.jpg
# /kaggle/input/dogs-vs-cats/test/test/4867.jpg
# /kaggle/input/dogs-vs-cats/test/test/11624.jpg
# /kaggle/input/dogs-vs-cats/test/test/6350.jpg
# /kaggle/input/dogs-vs-cats/test/test/2854.jpg
# /kaggle/input/dogs-vs-cats/test/test/3516.jpg
# /kaggle/input/dogs-vs-cats/test/test/5428.jpg
# /kaggle/input/dogs-vs-cats/test/test/1239.jpg
# /kaggle/input/dogs-vs-cats/test/test/1816.jpg
# /kaggle/input/dogs-vs-cats/test/test/3763.jpg
# /kaggle/input/dogs-vs-cats/test/test/7647.jpg
# /kaggle/input/dogs-vs-cats/test/test/6079.jpg
# /kaggle/input/dogs-vs-cats/test/test/6367.jpg
# /kaggle/input/dogs-vs-cats/test/test/8687.jpg
# /kaggle/input/dogs-vs-cats/test/test/8458.jpg
# /kaggle/input/dogs-vs-cats/test/test/312.jpg
# /kaggle/input/dogs-vs-cats/test/test/5820.jpg
# /kaggle/input/dogs-vs-cats/test/test/109.jpg
# /kaggle/input/dogs-vs-cats/test/test/8093.jpg
# /kaggle/input/dogs-vs-cats/test/test/10061.jpg
# /kaggle/input/dogs-vs-cats/test/test/4024.jpg
# /kaggle/input/dogs-vs-cats/test/test/2205.jpg
# /kaggle/input/dogs-vs-cats/test/test/4930.jpg
# /kaggle/input/dogs-vs-cats/test/test/10350.jpg
# /kaggle/input/dogs-vs-cats/test/test/10046.jpg
# /kaggle/input/dogs-vs-cats/test/test/1259.jpg
# /kaggle/input/dogs-vs-cats/test/test/196.jpg
# /kaggle/input/dogs-vs-cats/test/test/3614.jpg
# /kaggle/input/dogs-vs-cats/test/test/11888.jpg
# /kaggle/input/dogs-vs-cats/test/test/1835.jpg
# /kaggle/input/dogs-vs-cats/test/test/12237.jpg
# /kaggle/input/dogs-vs-cats/test/test/3409.jpg
# /kaggle/input/dogs-vs-cats/test/test/1164.jpg
# /kaggle/input/dogs-vs-cats/test/test/5166.jpg
# /kaggle/input/dogs-vs-cats/test/test/5510.jpg
# /kaggle/input/dogs-vs-cats/test/test/11050.jpg
# /kaggle/input/dogs-vs-cats/test/test/8509.jpg
# /kaggle/input/dogs-vs-cats/test/test/10787.jpg
# /kaggle/input/dogs-vs-cats/test/test/3215.jpg
# /kaggle/input/dogs-vs-cats/test/test/6438.jpg
# /kaggle/input/dogs-vs-cats/test/test/888.jpg
# /kaggle/input/dogs-vs-cats/test/test/3042.jpg
# /kaggle/input/dogs-vs-cats/test/test/9621.jpg
# /kaggle/input/dogs-vs-cats/test/test/2256.jpg
# /kaggle/input/dogs-vs-cats/test/test/4496.jpg
# /kaggle/input/dogs-vs-cats/test/test/12385.jpg
# /kaggle/input/dogs-vs-cats/test/test/8597.jpg
# /kaggle/input/dogs-vs-cats/test/test/6413.jpg
# /kaggle/input/dogs-vs-cats/test/test/4023.jpg
# /kaggle/input/dogs-vs-cats/test/test/4780.jpg
# /kaggle/input/dogs-vs-cats/test/test/3437.jpg
# /kaggle/input/dogs-vs-cats/test/test/1759.jpg
# /kaggle/input/dogs-vs-cats/test/test/8814.jpg
# /kaggle/input/dogs-vs-cats/test/test/3104.jpg
# /kaggle/input/dogs-vs-cats/test/test/6674.jpg
# /kaggle/input/dogs-vs-cats/test/test/10250.jpg
# /kaggle/input/dogs-vs-cats/test/test/3851.jpg
# /kaggle/input/dogs-vs-cats/test/test/6280.jpg
# /kaggle/input/dogs-vs-cats/test/test/5143.jpg
# /kaggle/input/dogs-vs-cats/test/test/3894.jpg
# /kaggle/input/dogs-vs-cats/test/test/4188.jpg
# /kaggle/input/dogs-vs-cats/test/test/10508.jpg
# /kaggle/input/dogs-vs-cats/test/test/1236.jpg
# /kaggle/input/dogs-vs-cats/test/test/4486.jpg
# /kaggle/input/dogs-vs-cats/test/test/1167.jpg
# /kaggle/input/dogs-vs-cats/test/test/6478.jpg
# /kaggle/input/dogs-vs-cats/test/test/3694.jpg
# /kaggle/input/dogs-vs-cats/test/test/4137.jpg
# /kaggle/input/dogs-vs-cats/test/test/5960.jpg
# /kaggle/input/dogs-vs-cats/test/test/9059.jpg
# /kaggle/input/dogs-vs-cats/test/test/4244.jpg
# /kaggle/input/dogs-vs-cats/test/test/3379.jpg
# /kaggle/input/dogs-vs-cats/test/test/3396.jpg
# /kaggle/input/dogs-vs-cats/test/test/677.jpg
# /kaggle/input/dogs-vs-cats/test/test/2484.jpg
# /kaggle/input/dogs-vs-cats/test/test/8169.jpg
# /kaggle/input/dogs-vs-cats/test/test/8942.jpg
# /kaggle/input/dogs-vs-cats/test/test/543.jpg
# /kaggle/input/dogs-vs-cats/test/test/1631.jpg
# /kaggle/input/dogs-vs-cats/test/test/10966.jpg
# /kaggle/input/dogs-vs-cats/test/test/6988.jpg
# /kaggle/input/dogs-vs-cats/test/test/2038.jpg
# /kaggle/input/dogs-vs-cats/test/test/301.jpg
# /kaggle/input/dogs-vs-cats/test/test/10368.jpg
# /kaggle/input/dogs-vs-cats/test/test/8677.jpg
# /kaggle/input/dogs-vs-cats/test/test/8742.jpg
# /kaggle/input/dogs-vs-cats/test/test/10025.jpg
# /kaggle/input/dogs-vs-cats/test/test/11275.jpg
# /kaggle/input/dogs-vs-cats/test/test/6574.jpg
# /kaggle/input/dogs-vs-cats/test/test/7116.jpg
# /kaggle/input/dogs-vs-cats/test/test/3310.jpg
# /kaggle/input/dogs-vs-cats/test/test/4904.jpg
# /kaggle/input/dogs-vs-cats/test/test/4217.jpg
# /kaggle/input/dogs-vs-cats/test/test/11229.jpg
# /kaggle/input/dogs-vs-cats/test/test/2475.jpg
# /kaggle/input/dogs-vs-cats/test/test/8953.jpg
# /kaggle/input/dogs-vs-cats/test/test/8257.jpg
# /kaggle/input/dogs-vs-cats/test/test/9982.jpg
# /kaggle/input/dogs-vs-cats/test/test/8869.jpg
# /kaggle/input/dogs-vs-cats/test/test/11510.jpg
# /kaggle/input/dogs-vs-cats/test/test/4359.jpg
# /kaggle/input/dogs-vs-cats/test/test/8072.jpg
# /kaggle/input/dogs-vs-cats/test/test/3340.jpg
# /kaggle/input/dogs-vs-cats/test/test/7294.jpg
# /kaggle/input/dogs-vs-cats/test/test/6752.jpg
# /kaggle/input/dogs-vs-cats/test/test/2620.jpg
# /kaggle/input/dogs-vs-cats/test/test/6596.jpg
# /kaggle/input/dogs-vs-cats/test/test/5534.jpg
# /kaggle/input/dogs-vs-cats/test/test/5700.jpg
# /kaggle/input/dogs-vs-cats/test/test/4527.jpg
# /kaggle/input/dogs-vs-cats/test/test/1424.jpg
# /kaggle/input/dogs-vs-cats/test/test/6809.jpg
# /kaggle/input/dogs-vs-cats/test/test/4328.jpg
# /kaggle/input/dogs-vs-cats/test/test/11031.jpg
# /kaggle/input/dogs-vs-cats/test/test/3352.jpg
# /kaggle/input/dogs-vs-cats/test/test/349.jpg
# /kaggle/input/dogs-vs-cats/test/test/11711.jpg
# /kaggle/input/dogs-vs-cats/test/test/7605.jpg
# /kaggle/input/dogs-vs-cats/test/test/7750.jpg
# /kaggle/input/dogs-vs-cats/test/test/10523.jpg
# /kaggle/input/dogs-vs-cats/test/test/8852.jpg
# /kaggle/input/dogs-vs-cats/test/test/10119.jpg
# /kaggle/input/dogs-vs-cats/test/test/2873.jpg
# /kaggle/input/dogs-vs-cats/test/test/10260.jpg
# /kaggle/input/dogs-vs-cats/test/test/3263.jpg
# /kaggle/input/dogs-vs-cats/test/test/7966.jpg
# /kaggle/input/dogs-vs-cats/test/test/7067.jpg
# /kaggle/input/dogs-vs-cats/test/test/6986.jpg
# /kaggle/input/dogs-vs-cats/test/test/10822.jpg
# /kaggle/input/dogs-vs-cats/test/test/5914.jpg
# /kaggle/input/dogs-vs-cats/test/test/7734.jpg
# /kaggle/input/dogs-vs-cats/test/test/636.jpg
# /kaggle/input/dogs-vs-cats/test/test/3331.jpg
# /kaggle/input/dogs-vs-cats/test/test/3220.jpg
# /kaggle/input/dogs-vs-cats/test/test/4782.jpg
# /kaggle/input/dogs-vs-cats/test/test/7306.jpg
# /kaggle/input/dogs-vs-cats/test/test/1580.jpg
# /kaggle/input/dogs-vs-cats/test/test/4166.jpg
# /kaggle/input/dogs-vs-cats/test/test/11472.jpg
# /kaggle/input/dogs-vs-cats/test/test/5830.jpg
# /kaggle/input/dogs-vs-cats/test/test/1752.jpg
# /kaggle/input/dogs-vs-cats/test/test/504.jpg
# /kaggle/input/dogs-vs-cats/test/test/7017.jpg
# /kaggle/input/dogs-vs-cats/test/test/9993.jpg
# /kaggle/input/dogs-vs-cats/test/test/3813.jpg
# /kaggle/input/dogs-vs-cats/test/test/6702.jpg
# /kaggle/input/dogs-vs-cats/test/test/5089.jpg
# /kaggle/input/dogs-vs-cats/test/test/4966.jpg
# /kaggle/input/dogs-vs-cats/test/test/6308.jpg
# /kaggle/input/dogs-vs-cats/test/test/5270.jpg
# /kaggle/input/dogs-vs-cats/test/test/8083.jpg
# /kaggle/input/dogs-vs-cats/test/test/2303.jpg
# /kaggle/input/dogs-vs-cats/test/test/8918.jpg
# /kaggle/input/dogs-vs-cats/test/test/6537.jpg
# /kaggle/input/dogs-vs-cats/test/test/12263.jpg
# /kaggle/input/dogs-vs-cats/test/test/5809.jpg
# /kaggle/input/dogs-vs-cats/test/test/8281.jpg
# /kaggle/input/dogs-vs-cats/test/test/2301.jpg
# /kaggle/input/dogs-vs-cats/test/test/6517.jpg
# /kaggle/input/dogs-vs-cats/test/test/7695.jpg
# /kaggle/input/dogs-vs-cats/test/test/2101.jpg
# /kaggle/input/dogs-vs-cats/test/test/4612.jpg
# /kaggle/input/dogs-vs-cats/test/test/10690.jpg
# /kaggle/input/dogs-vs-cats/test/test/6905.jpg
# /kaggle/input/dogs-vs-cats/test/test/2934.jpg
# /kaggle/input/dogs-vs-cats/test/test/7071.jpg
# /kaggle/input/dogs-vs-cats/test/test/767.jpg
# /kaggle/input/dogs-vs-cats/test/test/4831.jpg
# /kaggle/input/dogs-vs-cats/test/test/10654.jpg
# /kaggle/input/dogs-vs-cats/test/test/7610.jpg
# /kaggle/input/dogs-vs-cats/test/test/12130.jpg
# /kaggle/input/dogs-vs-cats/test/test/7223.jpg
# /kaggle/input/dogs-vs-cats/test/test/8635.jpg
# /kaggle/input/dogs-vs-cats/test/test/4902.jpg
# /kaggle/input/dogs-vs-cats/test/test/10194.jpg
# /kaggle/input/dogs-vs-cats/test/test/12415.jpg
# /kaggle/input/dogs-vs-cats/test/test/5649.jpg
# /kaggle/input/dogs-vs-cats/test/test/9766.jpg
# /kaggle/input/dogs-vs-cats/test/test/10202.jpg
# /kaggle/input/dogs-vs-cats/test/test/1771.jpg
# /kaggle/input/dogs-vs-cats/test/test/1196.jpg
# /kaggle/input/dogs-vs-cats/test/test/9736.jpg
# /kaggle/input/dogs-vs-cats/test/test/2930.jpg
# /kaggle/input/dogs-vs-cats/test/test/8498.jpg
# /kaggle/input/dogs-vs-cats/test/test/5910.jpg
# /kaggle/input/dogs-vs-cats/test/test/1177.jpg
# /kaggle/input/dogs-vs-cats/test/test/11458.jpg
# /kaggle/input/dogs-vs-cats/test/test/8631.jpg
# /kaggle/input/dogs-vs-cats/test/test/3847.jpg
# /kaggle/input/dogs-vs-cats/test/test/8027.jpg
# /kaggle/input/dogs-vs-cats/test/test/12257.jpg
# /kaggle/input/dogs-vs-cats/test/test/8445.jpg
# /kaggle/input/dogs-vs-cats/test/test/551.jpg
# /kaggle/input/dogs-vs-cats/test/test/5553.jpg
# /kaggle/input/dogs-vs-cats/test/test/4954.jpg
# /kaggle/input/dogs-vs-cats/test/test/3202.jpg
# /kaggle/input/dogs-vs-cats/test/test/12005.jpg
# /kaggle/input/dogs-vs-cats/test/test/11076.jpg
# /kaggle/input/dogs-vs-cats/test/test/8285.jpg
# /kaggle/input/dogs-vs-cats/test/test/6943.jpg
# /kaggle/input/dogs-vs-cats/test/test/6670.jpg
# /kaggle/input/dogs-vs-cats/test/test/12307.jpg
# /kaggle/input/dogs-vs-cats/test/test/3660.jpg
# /kaggle/input/dogs-vs-cats/test/test/6456.jpg
# /kaggle/input/dogs-vs-cats/test/test/12077.jpg
# /kaggle/input/dogs-vs-cats/test/test/9494.jpg
# /kaggle/input/dogs-vs-cats/test/test/5575.jpg
# /kaggle/input/dogs-vs-cats/test/test/7572.jpg
# /kaggle/input/dogs-vs-cats/test/test/7227.jpg
# /kaggle/input/dogs-vs-cats/test/test/8734.jpg
# /kaggle/input/dogs-vs-cats/test/test/5376.jpg
# /kaggle/input/dogs-vs-cats/test/test/9288.jpg
# /kaggle/input/dogs-vs-cats/test/test/10929.jpg
# /kaggle/input/dogs-vs-cats/test/test/6539.jpg
# /kaggle/input/dogs-vs-cats/test/test/3857.jpg
# /kaggle/input/dogs-vs-cats/test/test/8946.jpg
# /kaggle/input/dogs-vs-cats/test/test/7106.jpg
# /kaggle/input/dogs-vs-cats/test/test/4493.jpg
# /kaggle/input/dogs-vs-cats/test/test/6037.jpg
# /kaggle/input/dogs-vs-cats/test/test/2370.jpg
# /kaggle/input/dogs-vs-cats/test/test/2323.jpg
# /kaggle/input/dogs-vs-cats/test/test/10960.jpg
# /kaggle/input/dogs-vs-cats/test/test/12069.jpg
# /kaggle/input/dogs-vs-cats/test/test/9538.jpg
# /kaggle/input/dogs-vs-cats/test/test/10220.jpg
# /kaggle/input/dogs-vs-cats/test/test/9544.jpg
# /kaggle/input/dogs-vs-cats/test/test/8581.jpg
# /kaggle/input/dogs-vs-cats/test/test/1993.jpg
# /kaggle/input/dogs-vs-cats/test/test/11469.jpg
# /kaggle/input/dogs-vs-cats/test/test/11563.jpg
# /kaggle/input/dogs-vs-cats/test/test/8155.jpg
# /kaggle/input/dogs-vs-cats/test/test/7836.jpg
# /kaggle/input/dogs-vs-cats/test/test/8720.jpg
# /kaggle/input/dogs-vs-cats/test/test/7179.jpg
# /kaggle/input/dogs-vs-cats/test/test/9216.jpg
# /kaggle/input/dogs-vs-cats/test/test/5614.jpg
# /kaggle/input/dogs-vs-cats/test/test/43.jpg
# /kaggle/input/dogs-vs-cats/test/test/10662.jpg
# /kaggle/input/dogs-vs-cats/test/test/5079.jpg
# /kaggle/input/dogs-vs-cats/test/test/8410.jpg
# /kaggle/input/dogs-vs-cats/test/test/3638.jpg
# /kaggle/input/dogs-vs-cats/test/test/6151.jpg
# /kaggle/input/dogs-vs-cats/test/test/1457.jpg
# /kaggle/input/dogs-vs-cats/test/test/609.jpg
# /kaggle/input/dogs-vs-cats/test/test/9410.jpg
# /kaggle/input/dogs-vs-cats/test/test/7256.jpg
# /kaggle/input/dogs-vs-cats/test/test/11931.jpg
# /kaggle/input/dogs-vs-cats/test/test/8558.jpg
# /kaggle/input/dogs-vs-cats/test/test/11780.jpg
# /kaggle/input/dogs-vs-cats/test/test/9328.jpg
# /kaggle/input/dogs-vs-cats/test/test/9865.jpg
# /kaggle/input/dogs-vs-cats/test/test/1312.jpg
# /kaggle/input/dogs-vs-cats/test/test/3262.jpg
# /kaggle/input/dogs-vs-cats/test/test/10255.jpg
# /kaggle/input/dogs-vs-cats/test/test/2526.jpg
# /kaggle/input/dogs-vs-cats/test/test/8811.jpg
# /kaggle/input/dogs-vs-cats/test/test/12142.jpg
# /kaggle/input/dogs-vs-cats/test/test/2646.jpg
# /kaggle/input/dogs-vs-cats/test/test/10439.jpg
# /kaggle/input/dogs-vs-cats/test/test/5165.jpg
# /kaggle/input/dogs-vs-cats/test/test/5609.jpg
# /kaggle/input/dogs-vs-cats/test/test/10965.jpg
# /kaggle/input/dogs-vs-cats/test/test/3701.jpg
# /kaggle/input/dogs-vs-cats/test/test/8041.jpg
# /kaggle/input/dogs-vs-cats/test/test/7257.jpg
# /kaggle/input/dogs-vs-cats/test/test/4928.jpg
# /kaggle/input/dogs-vs-cats/test/test/5019.jpg
# /kaggle/input/dogs-vs-cats/test/test/7906.jpg
# /kaggle/input/dogs-vs-cats/test/test/7589.jpg
# /kaggle/input/dogs-vs-cats/test/test/6849.jpg
# /kaggle/input/dogs-vs-cats/test/test/1150.jpg
# /kaggle/input/dogs-vs-cats/test/test/1221.jpg
# /kaggle/input/dogs-vs-cats/test/test/4364.jpg
# /kaggle/input/dogs-vs-cats/test/test/5787.jpg
# /kaggle/input/dogs-vs-cats/test/test/12229.jpg
# /kaggle/input/dogs-vs-cats/test/test/8752.jpg
# /kaggle/input/dogs-vs-cats/test/test/4285.jpg
# /kaggle/input/dogs-vs-cats/test/test/5371.jpg
# /kaggle/input/dogs-vs-cats/test/test/9909.jpg
# /kaggle/input/dogs-vs-cats/test/test/1848.jpg
# /kaggle/input/dogs-vs-cats/test/test/9560.jpg
# /kaggle/input/dogs-vs-cats/test/test/10524.jpg
# /kaggle/input/dogs-vs-cats/test/test/6551.jpg
# /kaggle/input/dogs-vs-cats/test/test/12054.jpg
# /kaggle/input/dogs-vs-cats/test/test/3818.jpg
# /kaggle/input/dogs-vs-cats/test/test/8048.jpg
# /kaggle/input/dogs-vs-cats/test/test/8621.jpg
# /kaggle/input/dogs-vs-cats/test/test/7441.jpg
# /kaggle/input/dogs-vs-cats/test/test/3748.jpg
# /kaggle/input/dogs-vs-cats/test/test/6053.jpg
# /kaggle/input/dogs-vs-cats/test/test/5008.jpg
# /kaggle/input/dogs-vs-cats/test/test/6840.jpg
# /kaggle/input/dogs-vs-cats/test/test/3267.jpg
# /kaggle/input/dogs-vs-cats/test/test/7924.jpg
# /kaggle/input/dogs-vs-cats/test/test/10574.jpg
# /kaggle/input/dogs-vs-cats/test/test/4558.jpg
# /kaggle/input/dogs-vs-cats/test/test/7880.jpg
# /kaggle/input/dogs-vs-cats/test/test/3343.jpg
# /kaggle/input/dogs-vs-cats/test/test/9820.jpg
# /kaggle/input/dogs-vs-cats/test/test/10794.jpg
# /kaggle/input/dogs-vs-cats/test/test/1931.jpg
# /kaggle/input/dogs-vs-cats/test/test/2609.jpg
# /kaggle/input/dogs-vs-cats/test/test/5823.jpg
# /kaggle/input/dogs-vs-cats/test/test/5274.jpg
# /kaggle/input/dogs-vs-cats/test/test/2993.jpg
# /kaggle/input/dogs-vs-cats/test/test/4794.jpg
# /kaggle/input/dogs-vs-cats/test/test/10687.jpg
# /kaggle/input/dogs-vs-cats/test/test/1933.jpg
# /kaggle/input/dogs-vs-cats/test/test/11176.jpg
# /kaggle/input/dogs-vs-cats/test/test/12489.jpg
# /kaggle/input/dogs-vs-cats/test/test/3049.jpg
# /kaggle/input/dogs-vs-cats/test/test/6500.jpg
# /kaggle/input/dogs-vs-cats/test/test/11901.jpg
# /kaggle/input/dogs-vs-cats/test/test/7511.jpg
# /kaggle/input/dogs-vs-cats/test/test/8710.jpg
# /kaggle/input/dogs-vs-cats/test/test/12346.jpg
# /kaggle/input/dogs-vs-cats/test/test/10229.jpg
# /kaggle/input/dogs-vs-cats/test/test/10004.jpg
# /kaggle/input/dogs-vs-cats/test/test/1898.jpg
# /kaggle/input/dogs-vs-cats/test/test/2534.jpg
# /kaggle/input/dogs-vs-cats/test/test/8628.jpg
# /kaggle/input/dogs-vs-cats/test/test/10764.jpg
# /kaggle/input/dogs-vs-cats/test/test/11315.jpg
# /kaggle/input/dogs-vs-cats/test/test/8822.jpg
# /kaggle/input/dogs-vs-cats/test/test/2575.jpg
# /kaggle/input/dogs-vs-cats/test/test/12393.jpg
# /kaggle/input/dogs-vs-cats/test/test/8249.jpg
# /kaggle/input/dogs-vs-cats/test/test/10406.jpg
# /kaggle/input/dogs-vs-cats/test/test/4552.jpg
# /kaggle/input/dogs-vs-cats/test/test/12434.jpg
# /kaggle/input/dogs-vs-cats/test/test/170.jpg
# /kaggle/input/dogs-vs-cats/test/test/4643.jpg
# /kaggle/input/dogs-vs-cats/test/test/9880.jpg
# /kaggle/input/dogs-vs-cats/test/test/4393.jpg
# /kaggle/input/dogs-vs-cats/test/test/4015.jpg
# /kaggle/input/dogs-vs-cats/test/test/7404.jpg
# /kaggle/input/dogs-vs-cats/test/test/12279.jpg
# /kaggle/input/dogs-vs-cats/test/test/6239.jpg
# /kaggle/input/dogs-vs-cats/test/test/293.jpg
# /kaggle/input/dogs-vs-cats/test/test/6827.jpg
# /kaggle/input/dogs-vs-cats/test/test/6206.jpg
# /kaggle/input/dogs-vs-cats/test/test/8287.jpg
# /kaggle/input/dogs-vs-cats/test/test/6136.jpg
# /kaggle/input/dogs-vs-cats/test/test/1794.jpg
# /kaggle/input/dogs-vs-cats/test/test/1336.jpg
# /kaggle/input/dogs-vs-cats/test/test/9512.jpg
# /kaggle/input/dogs-vs-cats/test/test/7149.jpg
# /kaggle/input/dogs-vs-cats/test/test/4573.jpg
# /kaggle/input/dogs-vs-cats/test/test/7454.jpg
# /kaggle/input/dogs-vs-cats/test/test/9828.jpg
# /kaggle/input/dogs-vs-cats/test/test/4122.jpg
# /kaggle/input/dogs-vs-cats/test/test/3812.jpg
# /kaggle/input/dogs-vs-cats/test/test/103.jpg
# /kaggle/input/dogs-vs-cats/test/test/12412.jpg
# /kaggle/input/dogs-vs-cats/test/test/8602.jpg
# /kaggle/input/dogs-vs-cats/test/test/5928.jpg
# /kaggle/input/dogs-vs-cats/test/test/6758.jpg
# /kaggle/input/dogs-vs-cats/test/test/4298.jpg
# /kaggle/input/dogs-vs-cats/test/test/3578.jpg
# /kaggle/input/dogs-vs-cats/test/test/9966.jpg
# /kaggle/input/dogs-vs-cats/test/test/8092.jpg
# /kaggle/input/dogs-vs-cats/test/test/3462.jpg
# /kaggle/input/dogs-vs-cats/test/test/10027.jpg
# /kaggle/input/dogs-vs-cats/test/test/8444.jpg
# /kaggle/input/dogs-vs-cats/test/test/6393.jpg
# /kaggle/input/dogs-vs-cats/test/test/9471.jpg
# /kaggle/input/dogs-vs-cats/test/test/1096.jpg
# /kaggle/input/dogs-vs-cats/test/test/1688.jpg
# /kaggle/input/dogs-vs-cats/test/test/4773.jpg
# /kaggle/input/dogs-vs-cats/test/test/2407.jpg
# /kaggle/input/dogs-vs-cats/test/test/10954.jpg
# /kaggle/input/dogs-vs-cats/test/test/4568.jpg
# /kaggle/input/dogs-vs-cats/test/test/4011.jpg
# /kaggle/input/dogs-vs-cats/test/test/8830.jpg
# /kaggle/input/dogs-vs-cats/test/test/9740.jpg
# /kaggle/input/dogs-vs-cats/test/test/995.jpg
# /kaggle/input/dogs-vs-cats/test/test/9423.jpg
# /kaggle/input/dogs-vs-cats/test/test/2302.jpg
# /kaggle/input/dogs-vs-cats/test/test/8010.jpg
# /kaggle/input/dogs-vs-cats/test/test/11615.jpg
# /kaggle/input/dogs-vs-cats/test/test/5129.jpg
# /kaggle/input/dogs-vs-cats/test/test/1141.jpg
# /kaggle/input/dogs-vs-cats/test/test/165.jpg
# /kaggle/input/dogs-vs-cats/test/test/11611.jpg
# /kaggle/input/dogs-vs-cats/test/test/11643.jpg
# /kaggle/input/dogs-vs-cats/test/test/1400.jpg
# /kaggle/input/dogs-vs-cats/test/test/7818.jpg
# /kaggle/input/dogs-vs-cats/test/test/532.jpg
# /kaggle/input/dogs-vs-cats/test/test/8252.jpg
# /kaggle/input/dogs-vs-cats/test/test/859.jpg
# /kaggle/input/dogs-vs-cats/test/test/9528.jpg
# /kaggle/input/dogs-vs-cats/test/test/6694.jpg
# /kaggle/input/dogs-vs-cats/test/test/11547.jpg
# /kaggle/input/dogs-vs-cats/test/test/1873.jpg
# /kaggle/input/dogs-vs-cats/test/test/1602.jpg
# /kaggle/input/dogs-vs-cats/test/test/9001.jpg
# /kaggle/input/dogs-vs-cats/test/test/8590.jpg
# /kaggle/input/dogs-vs-cats/test/test/3691.jpg
# /kaggle/input/dogs-vs-cats/test/test/8344.jpg
# /kaggle/input/dogs-vs-cats/test/test/6374.jpg
# /kaggle/input/dogs-vs-cats/test/test/2071.jpg
# /kaggle/input/dogs-vs-cats/test/test/9866.jpg
# /kaggle/input/dogs-vs-cats/test/test/7322.jpg
# /kaggle/input/dogs-vs-cats/test/test/7757.jpg
# /kaggle/input/dogs-vs-cats/test/test/8966.jpg
# /kaggle/input/dogs-vs-cats/test/test/1494.jpg
# /kaggle/input/dogs-vs-cats/test/test/8373.jpg
# /kaggle/input/dogs-vs-cats/test/test/11762.jpg
# /kaggle/input/dogs-vs-cats/test/test/2882.jpg
# /kaggle/input/dogs-vs-cats/test/test/9224.jpg
# /kaggle/input/dogs-vs-cats/test/test/1460.jpg
# /kaggle/input/dogs-vs-cats/test/test/6939.jpg
# /kaggle/input/dogs-vs-cats/test/test/10969.jpg
# /kaggle/input/dogs-vs-cats/test/test/9540.jpg
# /kaggle/input/dogs-vs-cats/test/test/6815.jpg
# /kaggle/input/dogs-vs-cats/test/test/8270.jpg
# /kaggle/input/dogs-vs-cats/test/test/7276.jpg
# /kaggle/input/dogs-vs-cats/test/test/9170.jpg
# /kaggle/input/dogs-vs-cats/test/test/5974.jpg
# /kaggle/input/dogs-vs-cats/test/test/2758.jpg
# /kaggle/input/dogs-vs-cats/test/test/9188.jpg
# /kaggle/input/dogs-vs-cats/test/test/3423.jpg
# /kaggle/input/dogs-vs-cats/test/test/1900.jpg
# /kaggle/input/dogs-vs-cats/test/test/8038.jpg
# /kaggle/input/dogs-vs-cats/test/test/10390.jpg
# /kaggle/input/dogs-vs-cats/test/test/262.jpg
# /kaggle/input/dogs-vs-cats/test/test/1235.jpg
# /kaggle/input/dogs-vs-cats/test/test/3605.jpg
# /kaggle/input/dogs-vs-cats/test/test/1773.jpg
# /kaggle/input/dogs-vs-cats/test/test/10476.jpg
# /kaggle/input/dogs-vs-cats/test/test/7463.jpg
# /kaggle/input/dogs-vs-cats/test/test/1065.jpg
# /kaggle/input/dogs-vs-cats/test/test/5884.jpg
# /kaggle/input/dogs-vs-cats/test/test/8775.jpg
# /kaggle/input/dogs-vs-cats/test/test/11370.jpg
# /kaggle/input/dogs-vs-cats/test/test/8332.jpg
# /kaggle/input/dogs-vs-cats/test/test/5888.jpg
# /kaggle/input/dogs-vs-cats/test/test/121.jpg
# /kaggle/input/dogs-vs-cats/test/test/7833.jpg
# /kaggle/input/dogs-vs-cats/test/test/2201.jpg
# /kaggle/input/dogs-vs-cats/test/test/4416.jpg
# /kaggle/input/dogs-vs-cats/test/test/9627.jpg
# /kaggle/input/dogs-vs-cats/test/test/7742.jpg
# /kaggle/input/dogs-vs-cats/test/test/10997.jpg
# /kaggle/input/dogs-vs-cats/test/test/765.jpg
# /kaggle/input/dogs-vs-cats/test/test/5988.jpg
# /kaggle/input/dogs-vs-cats/test/test/10872.jpg
# /kaggle/input/dogs-vs-cats/test/test/4371.jpg
# /kaggle/input/dogs-vs-cats/test/test/7594.jpg
# /kaggle/input/dogs-vs-cats/test/test/2997.jpg
# /kaggle/input/dogs-vs-cats/test/test/8403.jpg
# /kaggle/input/dogs-vs-cats/test/test/3100.jpg
# /kaggle/input/dogs-vs-cats/test/test/8824.jpg
# /kaggle/input/dogs-vs-cats/test/test/2059.jpg
# /kaggle/input/dogs-vs-cats/test/test/2776.jpg
# /kaggle/input/dogs-vs-cats/test/test/9884.jpg
# /kaggle/input/dogs-vs-cats/test/test/9245.jpg
# /kaggle/input/dogs-vs-cats/test/test/326.jpg
# /kaggle/input/dogs-vs-cats/test/test/2262.jpg
# /kaggle/input/dogs-vs-cats/test/test/10266.jpg
# /kaggle/input/dogs-vs-cats/test/test/8142.jpg
# /kaggle/input/dogs-vs-cats/test/test/2527.jpg
# /kaggle/input/dogs-vs-cats/test/test/10146.jpg
# /kaggle/input/dogs-vs-cats/test/test/7390.jpg
# /kaggle/input/dogs-vs-cats/test/test/8305.jpg
# /kaggle/input/dogs-vs-cats/test/test/9944.jpg
# /kaggle/input/dogs-vs-cats/test/test/1817.jpg
# /kaggle/input/dogs-vs-cats/test/test/5423.jpg
# /kaggle/input/dogs-vs-cats/test/test/7189.jpg
# /kaggle/input/dogs-vs-cats/test/test/10127.jpg
# /kaggle/input/dogs-vs-cats/test/test/2012.jpg
# /kaggle/input/dogs-vs-cats/test/test/1189.jpg
# /kaggle/input/dogs-vs-cats/test/test/624.jpg
# /kaggle/input/dogs-vs-cats/test/test/11809.jpg
# /kaggle/input/dogs-vs-cats/test/test/9184.jpg
# /kaggle/input/dogs-vs-cats/test/test/3752.jpg
# /kaggle/input/dogs-vs-cats/test/test/2192.jpg
# /kaggle/input/dogs-vs-cats/test/test/655.jpg
# /kaggle/input/dogs-vs-cats/test/test/8459.jpg
# /kaggle/input/dogs-vs-cats/test/test/8751.jpg
# /kaggle/input/dogs-vs-cats/test/test/8639.jpg
# /kaggle/input/dogs-vs-cats/test/test/854.jpg
# /kaggle/input/dogs-vs-cats/test/test/4692.jpg
# /kaggle/input/dogs-vs-cats/test/test/10248.jpg
# /kaggle/input/dogs-vs-cats/test/test/6497.jpg
# /kaggle/input/dogs-vs-cats/test/test/1990.jpg
# /kaggle/input/dogs-vs-cats/test/test/11681.jpg
# /kaggle/input/dogs-vs-cats/test/test/8077.jpg
# /kaggle/input/dogs-vs-cats/test/test/486.jpg
# /kaggle/input/dogs-vs-cats/test/test/5723.jpg
# /kaggle/input/dogs-vs-cats/test/test/6170.jpg
# /kaggle/input/dogs-vs-cats/test/test/2883.jpg
# /kaggle/input/dogs-vs-cats/test/test/9361.jpg
# /kaggle/input/dogs-vs-cats/test/test/1642.jpg
# /kaggle/input/dogs-vs-cats/test/test/6874.jpg
# /kaggle/input/dogs-vs-cats/test/test/4477.jpg
# /kaggle/input/dogs-vs-cats/test/test/11122.jpg
# /kaggle/input/dogs-vs-cats/test/test/4732.jpg
# /kaggle/input/dogs-vs-cats/test/test/8766.jpg
# /kaggle/input/dogs-vs-cats/test/test/10817.jpg
# /kaggle/input/dogs-vs-cats/test/test/675.jpg
# /kaggle/input/dogs-vs-cats/test/test/2183.jpg
# /kaggle/input/dogs-vs-cats/test/test/275.jpg
# /kaggle/input/dogs-vs-cats/test/test/9928.jpg
# /kaggle/input/dogs-vs-cats/test/test/7182.jpg
# /kaggle/input/dogs-vs-cats/test/test/2779.jpg
# /kaggle/input/dogs-vs-cats/test/test/8930.jpg
# /kaggle/input/dogs-vs-cats/test/test/4960.jpg
# /kaggle/input/dogs-vs-cats/test/test/6978.jpg
# /kaggle/input/dogs-vs-cats/test/test/3330.jpg
# /kaggle/input/dogs-vs-cats/test/test/5144.jpg
# /kaggle/input/dogs-vs-cats/test/test/475.jpg
# /kaggle/input/dogs-vs-cats/test/test/49.jpg
# /kaggle/input/dogs-vs-cats/test/test/762.jpg
# /kaggle/input/dogs-vs-cats/test/test/10442.jpg
# /kaggle/input/dogs-vs-cats/test/test/770.jpg
# /kaggle/input/dogs-vs-cats/test/test/8860.jpg
# /kaggle/input/dogs-vs-cats/test/test/10768.jpg
# /kaggle/input/dogs-vs-cats/test/test/6968.jpg
# /kaggle/input/dogs-vs-cats/test/test/11731.jpg
# /kaggle/input/dogs-vs-cats/test/test/7574.jpg
# /kaggle/input/dogs-vs-cats/test/test/5693.jpg
# /kaggle/input/dogs-vs-cats/test/test/8625.jpg
# /kaggle/input/dogs-vs-cats/test/test/5753.jpg
# /kaggle/input/dogs-vs-cats/test/test/8645.jpg
# /kaggle/input/dogs-vs-cats/test/test/7375.jpg
# /kaggle/input/dogs-vs-cats/test/test/12245.jpg
# /kaggle/input/dogs-vs-cats/test/test/10646.jpg
# /kaggle/input/dogs-vs-cats/test/test/8405.jpg
# /kaggle/input/dogs-vs-cats/test/test/1578.jpg
# /kaggle/input/dogs-vs-cats/test/test/11413.jpg
# /kaggle/input/dogs-vs-cats/test/test/3178.jpg
# /kaggle/input/dogs-vs-cats/test/test/8589.jpg
# /kaggle/input/dogs-vs-cats/test/test/9605.jpg
# /kaggle/input/dogs-vs-cats/test/test/1606.jpg
# /kaggle/input/dogs-vs-cats/test/test/11395.jpg
# /kaggle/input/dogs-vs-cats/test/test/5719.jpg
# /kaggle/input/dogs-vs-cats/test/test/8593.jpg
# /kaggle/input/dogs-vs-cats/test/test/1056.jpg
# /kaggle/input/dogs-vs-cats/test/test/11300.jpg
# /kaggle/input/dogs-vs-cats/test/test/8913.jpg
# /kaggle/input/dogs-vs-cats/test/test/11823.jpg
# /kaggle/input/dogs-vs-cats/test/test/2374.jpg
# /kaggle/input/dogs-vs-cats/test/test/3545.jpg
# /kaggle/input/dogs-vs-cats/test/test/8333.jpg
# /kaggle/input/dogs-vs-cats/test/test/12445.jpg
# /kaggle/input/dogs-vs-cats/test/test/1343.jpg
# /kaggle/input/dogs-vs-cats/test/test/8058.jpg
# /kaggle/input/dogs-vs-cats/test/test/9881.jpg
# /kaggle/input/dogs-vs-cats/test/test/5594.jpg
# /kaggle/input/dogs-vs-cats/test/test/2168.jpg
# /kaggle/input/dogs-vs-cats/test/test/6828.jpg
# /kaggle/input/dogs-vs-cats/test/test/1479.jpg
# /kaggle/input/dogs-vs-cats/test/test/9371.jpg
# /kaggle/input/dogs-vs-cats/test/test/2147.jpg
# /kaggle/input/dogs-vs-cats/test/test/8972.jpg
# /kaggle/input/dogs-vs-cats/test/test/5978.jpg
# /kaggle/input/dogs-vs-cats/test/test/9089.jpg
# /kaggle/input/dogs-vs-cats/test/test/7674.jpg
# /kaggle/input/dogs-vs-cats/test/test/3012.jpg
# /kaggle/input/dogs-vs-cats/test/test/7586.jpg
# /kaggle/input/dogs-vs-cats/test/test/216.jpg
# /kaggle/input/dogs-vs-cats/test/test/5119.jpg
# /kaggle/input/dogs-vs-cats/test/test/3686.jpg
# /kaggle/input/dogs-vs-cats/test/test/7810.jpg
# /kaggle/input/dogs-vs-cats/test/test/2988.jpg
# /kaggle/input/dogs-vs-cats/test/test/1385.jpg
# /kaggle/input/dogs-vs-cats/test/test/6928.jpg
# /kaggle/input/dogs-vs-cats/test/test/9470.jpg
# /kaggle/input/dogs-vs-cats/test/test/6294.jpg
# /kaggle/input/dogs-vs-cats/test/test/11512.jpg
# /kaggle/input/dogs-vs-cats/test/test/735.jpg
# /kaggle/input/dogs-vs-cats/test/test/9349.jpg
# /kaggle/input/dogs-vs-cats/test/test/4488.jpg
# /kaggle/input/dogs-vs-cats/test/test/11498.jpg
# /kaggle/input/dogs-vs-cats/test/test/8442.jpg
# /kaggle/input/dogs-vs-cats/test/test/12175.jpg
# /kaggle/input/dogs-vs-cats/test/test/12169.jpg
# /kaggle/input/dogs-vs-cats/test/test/7102.jpg
# /kaggle/input/dogs-vs-cats/test/test/7344.jpg
# /kaggle/input/dogs-vs-cats/test/test/9454.jpg
# /kaggle/input/dogs-vs-cats/test/test/4941.jpg
# /kaggle/input/dogs-vs-cats/test/test/10205.jpg
# /kaggle/input/dogs-vs-cats/test/test/1304.jpg
# /kaggle/input/dogs-vs-cats/test/test/9447.jpg
# /kaggle/input/dogs-vs-cats/test/test/10730.jpg
# /kaggle/input/dogs-vs-cats/test/test/557.jpg
# /kaggle/input/dogs-vs-cats/test/test/7293.jpg
# /kaggle/input/dogs-vs-cats/test/test/9565.jpg
# /kaggle/input/dogs-vs-cats/test/test/4237.jpg
# /kaggle/input/dogs-vs-cats/test/test/6316.jpg
# /kaggle/input/dogs-vs-cats/test/test/5610.jpg
# /kaggle/input/dogs-vs-cats/test/test/9812.jpg
# /kaggle/input/dogs-vs-cats/test/test/10874.jpg
# /kaggle/input/dogs-vs-cats/test/test/7199.jpg
# /kaggle/input/dogs-vs-cats/test/test/5760.jpg
# /kaggle/input/dogs-vs-cats/test/test/9058.jpg
# /kaggle/input/dogs-vs-cats/test/test/8548.jpg
# /kaggle/input/dogs-vs-cats/test/test/5125.jpg
# /kaggle/input/dogs-vs-cats/test/test/11724.jpg
# /kaggle/input/dogs-vs-cats/test/test/9654.jpg
# /kaggle/input/dogs-vs-cats/test/test/6461.jpg
# /kaggle/input/dogs-vs-cats/test/test/3587.jpg
# /kaggle/input/dogs-vs-cats/test/test/355.jpg
# /kaggle/input/dogs-vs-cats/test/test/5332.jpg
# /kaggle/input/dogs-vs-cats/test/test/233.jpg
# /kaggle/input/dogs-vs-cats/test/test/8081.jpg
# /kaggle/input/dogs-vs-cats/test/test/6401.jpg
# /kaggle/input/dogs-vs-cats/test/test/11827.jpg
# /kaggle/input/dogs-vs-cats/test/test/4176.jpg
# /kaggle/input/dogs-vs-cats/test/test/5385.jpg
# /kaggle/input/dogs-vs-cats/test/test/8640.jpg
# /kaggle/input/dogs-vs-cats/test/test/9748.jpg
# /kaggle/input/dogs-vs-cats/test/test/1910.jpg
# /kaggle/input/dogs-vs-cats/test/test/12151.jpg
# /kaggle/input/dogs-vs-cats/test/test/11501.jpg
# /kaggle/input/dogs-vs-cats/test/test/2052.jpg
# /kaggle/input/dogs-vs-cats/test/test/10369.jpg
# /kaggle/input/dogs-vs-cats/test/test/6452.jpg
# /kaggle/input/dogs-vs-cats/test/test/3113.jpg
# /kaggle/input/dogs-vs-cats/test/test/4012.jpg
# /kaggle/input/dogs-vs-cats/test/test/8945.jpg
# /kaggle/input/dogs-vs-cats/test/test/5689.jpg
# /kaggle/input/dogs-vs-cats/test/test/494.jpg
# /kaggle/input/dogs-vs-cats/test/test/2945.jpg
# /kaggle/input/dogs-vs-cats/test/test/10067.jpg
# /kaggle/input/dogs-vs-cats/test/test/3062.jpg
# /kaggle/input/dogs-vs-cats/test/test/1563.jpg
# /kaggle/input/dogs-vs-cats/test/test/5380.jpg
# /kaggle/input/dogs-vs-cats/test/test/717.jpg
# /kaggle/input/dogs-vs-cats/test/test/6202.jpg
# /kaggle/input/dogs-vs-cats/test/test/10136.jpg
# /kaggle/input/dogs-vs-cats/test/test/3912.jpg
# /kaggle/input/dogs-vs-cats/test/test/8658.jpg
# /kaggle/input/dogs-vs-cats/test/test/4677.jpg
# /kaggle/input/dogs-vs-cats/test/test/9855.jpg
# /kaggle/input/dogs-vs-cats/test/test/10115.jpg
# /kaggle/input/dogs-vs-cats/test/test/11966.jpg
# /kaggle/input/dogs-vs-cats/test/test/3903.jpg
# /kaggle/input/dogs-vs-cats/test/test/3956.jpg
# /kaggle/input/dogs-vs-cats/test/test/3588.jpg
# /kaggle/input/dogs-vs-cats/test/test/1474.jpg
# /kaggle/input/dogs-vs-cats/test/test/10378.jpg
# /kaggle/input/dogs-vs-cats/test/test/4989.jpg
# /kaggle/input/dogs-vs-cats/test/test/4399.jpg
# /kaggle/input/dogs-vs-cats/test/test/7587.jpg
# /kaggle/input/dogs-vs-cats/test/test/6750.jpg
# /kaggle/input/dogs-vs-cats/test/test/4144.jpg
# /kaggle/input/dogs-vs-cats/test/test/9997.jpg
# /kaggle/input/dogs-vs-cats/test/test/10218.jpg
# /kaggle/input/dogs-vs-cats/test/test/4157.jpg
# /kaggle/input/dogs-vs-cats/test/test/12058.jpg
# /kaggle/input/dogs-vs-cats/test/test/11015.jpg
# /kaggle/input/dogs-vs-cats/test/test/6822.jpg
# /kaggle/input/dogs-vs-cats/test/test/6781.jpg
# /kaggle/input/dogs-vs-cats/test/test/11799.jpg
# /kaggle/input/dogs-vs-cats/test/test/6474.jpg
# /kaggle/input/dogs-vs-cats/test/test/10644.jpg
# /kaggle/input/dogs-vs-cats/test/test/12315.jpg
# /kaggle/input/dogs-vs-cats/test/test/3014.jpg
# /kaggle/input/dogs-vs-cats/test/test/4131.jpg
# /kaggle/input/dogs-vs-cats/test/test/12341.jpg
# /kaggle/input/dogs-vs-cats/test/test/1679.jpg
# /kaggle/input/dogs-vs-cats/test/test/8243.jpg
# /kaggle/input/dogs-vs-cats/test/test/4783.jpg
# /kaggle/input/dogs-vs-cats/test/test/5831.jpg
# /kaggle/input/dogs-vs-cats/test/test/6554.jpg
# /kaggle/input/dogs-vs-cats/test/test/9772.jpg
# /kaggle/input/dogs-vs-cats/test/test/3116.jpg
# /kaggle/input/dogs-vs-cats/test/test/8686.jpg
# /kaggle/input/dogs-vs-cats/test/test/5862.jpg
# /kaggle/input/dogs-vs-cats/test/test/6686.jpg
# /kaggle/input/dogs-vs-cats/test/test/10432.jpg
# /kaggle/input/dogs-vs-cats/test/test/2216.jpg
# /kaggle/input/dogs-vs-cats/test/test/5215.jpg
# /kaggle/input/dogs-vs-cats/test/test/3120.jpg
# /kaggle/input/dogs-vs-cats/test/test/10101.jpg
# /kaggle/input/dogs-vs-cats/test/test/12038.jpg
# /kaggle/input/dogs-vs-cats/test/test/472.jpg
# /kaggle/input/dogs-vs-cats/test/test/8871.jpg
# /kaggle/input/dogs-vs-cats/test/test/4290.jpg
# /kaggle/input/dogs-vs-cats/test/test/10126.jpg
# /kaggle/input/dogs-vs-cats/test/test/1440.jpg
# /kaggle/input/dogs-vs-cats/test/test/10727.jpg
# /kaggle/input/dogs-vs-cats/test/test/9694.jpg
# /kaggle/input/dogs-vs-cats/test/test/621.jpg
# /kaggle/input/dogs-vs-cats/test/test/2805.jpg
# /kaggle/input/dogs-vs-cats/test/test/2615.jpg
# /kaggle/input/dogs-vs-cats/test/test/5941.jpg
# /kaggle/input/dogs-vs-cats/test/test/10113.jpg
# /kaggle/input/dogs-vs-cats/test/test/9663.jpg
# /kaggle/input/dogs-vs-cats/test/test/6018.jpg
# /kaggle/input/dogs-vs-cats/test/test/5395.jpg
# /kaggle/input/dogs-vs-cats/test/test/734.jpg
# /kaggle/input/dogs-vs-cats/test/test/7138.jpg
# /kaggle/input/dogs-vs-cats/test/test/230.jpg
# /kaggle/input/dogs-vs-cats/test/test/1335.jpg
# /kaggle/input/dogs-vs-cats/test/test/3675.jpg
# /kaggle/input/dogs-vs-cats/test/test/1489.jpg
# /kaggle/input/dogs-vs-cats/test/test/10621.jpg
# /kaggle/input/dogs-vs-cats/test/test/4211.jpg
# /kaggle/input/dogs-vs-cats/test/test/895.jpg
# /kaggle/input/dogs-vs-cats/test/test/3243.jpg
# /kaggle/input/dogs-vs-cats/test/test/4080.jpg
# /kaggle/input/dogs-vs-cats/test/test/8986.jpg
# /kaggle/input/dogs-vs-cats/test/test/7798.jpg
# /kaggle/input/dogs-vs-cats/test/test/2762.jpg
# /kaggle/input/dogs-vs-cats/test/test/5694.jpg
# /kaggle/input/dogs-vs-cats/test/test/417.jpg
# /kaggle/input/dogs-vs-cats/test/test/10545.jpg
# /kaggle/input/dogs-vs-cats/test/test/5450.jpg
# /kaggle/input/dogs-vs-cats/test/test/8683.jpg
# /kaggle/input/dogs-vs-cats/test/test/5593.jpg
# /kaggle/input/dogs-vs-cats/test/test/8881.jpg
# ...
# /kaggle/input/dogs-vs-cats/train/train/dog.2642.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10973.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4265.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.620.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1388.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3170.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7992.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1224.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7546.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4222.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9965.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6223.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1353.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11978.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3368.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10186.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9065.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7398.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6428.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.12167.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6661.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8837.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5574.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7846.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9423.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6357.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10990.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3729.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10501.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6120.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10811.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1615.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10767.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1196.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7493.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4618.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3279.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1179.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10350.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10181.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7880.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.2190.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2358.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.2969.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6340.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7864.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.208.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9736.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11568.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11086.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9161.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4248.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11920.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.12192.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7511.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.78.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7157.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11245.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2210.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1025.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3252.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4951.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9470.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5687.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4778.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11317.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9044.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5949.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3535.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5993.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1248.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10539.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.12009.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9512.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7053.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8574.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1389.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1285.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1811.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7181.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6691.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4374.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3402.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1552.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5000.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6708.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.824.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6802.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.34.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8119.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3547.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4782.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1824.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.236.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4178.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1974.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4154.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3295.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9822.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1873.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4780.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1776.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10631.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7265.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7687.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4005.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3615.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10106.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.12180.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6165.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6608.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7066.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6240.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6617.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11265.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5659.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10454.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.781.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3459.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5046.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.12247.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5439.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10794.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.2758.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5787.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6405.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5002.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1366.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7487.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10149.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11230.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11672.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6143.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10147.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3974.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.783.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6397.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.946.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7367.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2145.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.676.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11130.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4569.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7372.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1436.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5285.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7059.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3174.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9908.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8613.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6644.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7799.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5436.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9260.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.395.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.988.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9768.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1474.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6620.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4363.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7650.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6708.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4354.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1309.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.612.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1980.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1176.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5781.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1691.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9431.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6134.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11892.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1472.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4914.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9500.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8212.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6534.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6648.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7473.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5530.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10347.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5002.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10823.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7414.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8499.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1332.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11877.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9487.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6950.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10849.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10099.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6108.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9688.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9407.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6716.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11525.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6990.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5593.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11093.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6545.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5720.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7894.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6026.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10707.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11343.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9795.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6264.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5964.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6303.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5251.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5472.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7634.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9695.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3347.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9344.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6211.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9262.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6097.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9923.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8317.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5418.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1688.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.49.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3593.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1805.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6862.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3081.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7186.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2149.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.2288.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8310.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.312.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4168.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7836.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.6264.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.12266.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.2907.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1773.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9056.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1632.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4637.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4364.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7246.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7800.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8738.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.223.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7255.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8611.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10197.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.48.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1313.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5425.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11027.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4690.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1443.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.6506.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9441.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.855.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10681.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.5585.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3572.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2270.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4454.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1232.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2306.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.424.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8910.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4250.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8277.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4590.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1777.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.9449.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1247.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10459.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4695.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.10966.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.4213.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5010.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.11713.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.11469.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10447.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.12151.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3063.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7154.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.4295.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.10535.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2019.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.9061.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8701.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.5136.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7722.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.12393.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2730.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1835.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.2576.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3828.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.7524.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.2074.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.8425.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.1655.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.8172.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7949.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.12002.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.3538.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.7276.jpg
# /kaggle/input/dogs-vs-cats/train/train/dog.3530.jpg
# /kaggle/input/dogs-vs-cats/train/train/cat.1117.jpg

# %%
import os
import cv2
import random
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
print(os.listdir("../input/dogs-vs-cats"))
# Out:
# ['test', 'train']

# %%
train_dir = "/kaggle/input/dogs-vs-cats/train/train"
test_dir = "/kaggle/input/dogs-vs-cats/test/test"

print('number of training images - ',len(os.listdir(train_dir)))
print('number of testing images - ',len(os.listdir(test_dir)))
# Out:
# number of training images -  25000
# number of testing images -  12500

# %%
IMG_SIZE = 112

CATEGORIES = ["cat", "dog"]

# %%
CATEGORIES.index("cat")
# Out:
# 0

# %%
def create_training_data():
    training_data  = []
    images = []
    labels = []
    
    imagefiles = [os.path.join(train_dir,f) for f in os.listdir(train_dir)]
    for image in imagefiles:
        category = image.split('/')[-1].split('.')[0]
        img_array = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        training_data .append([new_array, CATEGORIES.index(category)])
        
    random.shuffle(training_data)
    for features,label in training_data:
        images.append(features)
        labels.append(label)
    images = np.array(images).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    
    return images, labels

# %%
images, labels = create_training_data()

# %%
len(images)
# Out:
# 25000

# %%
def create_testing_data():
    test_images  = []
    
    imagefiles = [os.path.join(test_dir,f) for f in os.listdir(test_dir)]
    for image in imagefiles:
        img_array = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        test_images .append(new_array)
        
    random.shuffle(test_images)
#     test_images = np.array(test_images).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    return test_images


test_images = create_testing_data()
len(test_images)
# Out:
# 12500

# %%
# standardizing between 0 to 255
X_train = images / 255.0
X_test = np.array(test_images).reshape(-1, IMG_SIZE, IMG_SIZE, 1) / 255.0

y_train = np.array(labels)

# convert from int to float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
len(test_images[0])
# Out:
# 112

# %%
from functools import partial

DefaultConv2D = partial(keras.layers.Conv2D,
                        kernel_size=3, activation='relu', padding="SAME")

model_AlexNet = keras.models.Sequential([
    DefaultConv2D(filters=6, kernel_size=5, padding="valid",input_shape=[112, 112, 1]),
    keras.layers.MaxPooling2D(pool_size=2, strides=2, padding="valid"),
    DefaultConv2D(filters=16, kernel_size=5),
    keras.layers.MaxPooling2D(pool_size=2, strides=2, padding="valid"),
    DefaultConv2D(filters=36),
    DefaultConv2D(filters=36),
    DefaultConv2D(filters=16),
    keras.layers.MaxPooling2D(pool_size=2, strides=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=100, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=2, activation='softmax')
])

# %%
model_AlexNet.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])
history = model_AlexNet.fit(X_train, y_train, epochs=10)
score = model_AlexNet.evaluate(X_train, y_train)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.6573 - accuracy: 0.5956
# Epoch 2/10
# 782/782 [==============================] - 6s 8ms/step - loss: 0.5237 - accuracy: 0.7446
# Epoch 3/10
# 782/782 [==============================] - 6s 8ms/step - loss: 0.4492 - accuracy: 0.7898
# Epoch 4/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.3954 - accuracy: 0.8233
# Epoch 5/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.3498 - accuracy: 0.8454
# Epoch 6/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.3155 - accuracy: 0.8622
# Epoch 7/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.2813 - accuracy: 0.8803
# Epoch 8/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.2534 - accuracy: 0.8937
# Epoch 9/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.2208 - accuracy: 0.9078
# Epoch 10/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1982 - accuracy: 0.9191
# 782/782 [==============================] - 3s 3ms/step - loss: 0.1508 - accuracy: 0.9387

# %%
predicted_classes = model_AlexNet.predict_classes(X_test)

#Let's Visualize some predicted images 
plt.figure(figsize=(10,10))
rand = np.random.randint(0,1000*2,25)
for i in range(len(rand)):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_images[rand[i]], cmap="gray")
    plt.xlabel(CATEGORIES[predicted_classes[rand[i]]])
